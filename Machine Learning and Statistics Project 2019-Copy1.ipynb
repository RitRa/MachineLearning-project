# %% [markdown]
# #### Boston House Prices dataset
#
# The boston dataset was first published in 1978 in a paper [Hedonic Housing Prices and the Demand for Clean Air ](http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.926.5532&rep=rep1&type=pdf) by Harrison and Rubenfield.  506 entries represent aggregated data about 14 features for homes in Boston and capture the Crime rate (CRIM), number of Rooms(RM), age(AGE) of owners and more. This dataset is widely used in many machine learning papers that address regression problems.
#
# #### Aims of this notebook:
#
# 1. Use **descriptive statistics** and plots to describe the Boston House Prices dataset.
# 2. Use **inferential statistics** to analyse whether there is a significant difference in median house prices between houses that are along the Charles river and those that aren’t. You should explain and discuss your findings within the notebook.
# 3. Use **keras** to create a neural network that can predict the median house price based on the other variables in the dataset.

# %% [markdown]
# ### Libraries used in this project

# %%
import numpy as np
import pandas as pd
# plots
import seaborn as sns
import matplotlib.pyplot as plt
# for creating folder for plots
import os
from random import random
# statistical analysis
import researchpy as rp
import statsmodels.api as sm
#for interactive widgets for charts
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets
# machine learning
import keras as kr
from keras.models import Sequential
from keras.layers import Dense
#from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
# Out:
# Using TensorFlow backend.

# %%
# importing the boston housing dataset
from sklearn.datasets import load_boston
boston_df = load_boston()

# %% [markdown]
# ## Exploring the data

# %%
# print the keys in the dataset
print(boston_df.keys())
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %% [markdown]
# To learn more about this dataset you can print the description

# %%
# DESC should tell us what the data is about
print(boston_df.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of UCI ML housing dataset.
# https://archive.ics.uci.edu/ml/machine-learning-databases/housing/
#
#
# This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression
# problems.
#
# .. topic:: References
#
#    - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#    - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.

# %%
# the feature name contain the columns of the dataset
print(boston_df.feature_names)
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %% [markdown]
# From inspecting the boston_df.filename, we can see that feature_names should be the columns and boston_df.data should be the rows

# %%
# create a new dataset called Boston using the feature_names as the columns
boston = pd.DataFrame(boston_df.data, columns=boston_df.feature_names)
# We are missing one column (MEDV). According to DESCR, Median Value (attribute 14) is usually the target.
boston['MEDV'] = boston_df.target

# Median value of owner-occupied homes in $1000's 
boston['MEDV'] = (boston['MEDV']*1000)

# glance at the data
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT     MEDV
# 0     15.3  396.90   4.98  24000.0
# 1     17.8  396.90   9.14  21600.0
# 2     17.8  392.83   4.03  34700.0
# 3     18.7  394.63   2.94  33400.0
# 4     18.7  396.90   5.33  36200.0

# %% [markdown]
# #### Date cleaning
# This is important for the machine learning part of the project
# - Check for null values, df.isnull().sum(). Luckily there is no null values in the dataset
# - Check for duplicates

# %% [markdown]
# There are 16 duplicates for MEDV of 50000.0. We need to remove them as they will throw off the predictions later in the project.

# %%
boston = (boston[boston.MEDV != 50000.0])

# %% [markdown]
# ## Part 1. Descriptive Statistics
# Use **descriptive statistics** and plots to describe the Boston House Prices dataset.
#
# Here we can quickly see the mean, standard deviation, min, max and various percentiles for the dataset.

# %%
# describe() gives us a quick overview of the dataset
summary = boston.describe()
summary = summary.transpose()
summary.round(2)
# Out:
#          count      mean      std      min       25%       50%       75%  \
# CRIM     490.0      3.64     8.72     0.01      0.08      0.25      3.65
# ZN       490.0     11.11    22.84     0.00      0.00      0.00     12.50
# INDUS    490.0     11.11     6.82     0.74      5.19      9.69     18.10
# CHAS     490.0      0.06     0.24     0.00      0.00      0.00      0.00
# NOX      490.0      0.55     0.12     0.38      0.45      0.54      0.62
# RM       490.0      6.25     0.65     3.56      5.88      6.18      6.58
# AGE      490.0     68.28    28.16     2.90     44.55     76.80     93.88
# DIS      490.0      3.83     2.11     1.14      2.11      3.28      5.21
# RAD      490.0      9.51     8.69     1.00      4.00      5.00     24.00
# TAX      490.0    408.00   168.07   187.00    280.25    330.00    666.00
# PTRATIO  490.0     18.52     2.11    12.60     17.40     19.10     20.20
# B        490.0    355.86    92.63     0.32    375.91    391.77    396.32
# LSTAT    490.0     12.92     7.08     1.98      7.35     11.68     17.12
# MEDV     490.0  21635.92  7865.30  5000.00  16700.00  20900.00  24675.00
#
#               max
# CRIM        88.98
# ZN         100.00
# INDUS       27.74
# CHAS         1.00
# NOX          0.87
# RM           8.78
# AGE        100.00
# DIS         12.13
# RAD         24.00
# TAX        711.00
# PTRATIO     22.00
# B          396.90
# LSTAT       37.97
# MEDV     48800.00

# %%
prices = boston['MEDV']
# TODO: Minimum price of the data
minimum_price = np.min(prices)

# TODO: Maximum price of the data
maximum_price = np.max(prices)

# TODO: Mean price of the data
mean_price = np.mean(prices)

# TODO: Median price of the data
median_price = np.median(prices)

# TODO: Standard deviation of prices of the data
std_price = np.std(prices)

# Show the calculated statistics
print ("Statistics for Boston housing dataset:")
print ("Minimum price: ${:,.2f}".format(minimum_price))
print ("Maximum price: ${:,.2f}".format(maximum_price))
print ("Mean price: ${:,.2f}".format(mean_price))
print( "Median price ${:,.2f}".format(median_price))
print ("Standard deviation of prices: ${:,.2f}".format(std_price))
# Out:
# Statistics for Boston housing dataset:
# Minimum price: $5,000.00
# Maximum price: $48,800.00
# Mean price: $21,635.92
# Median price $20,900.00
# Standard deviation of prices: $7,857.27

# %%
if not os.path.exists("plots/box"):
    os.makedirs("plots/box")

# random color for each plot     
import random
df_color = sns.color_palette("husl")
random.choice(df_color)

   
@interact

def box_plt(feature = list(boston.columns)):
    for i, value in enumerate(boston):
        sns.boxplot(boston[feature], orient="v", color=random.choice(df_color))
        plt.savefig("plots/box/box_" + str(i) + ".png")
# Out:
# interactive(children=(Dropdown(description='feature', options=('CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AG…

# %% [markdown]
# While researching this topic, I read this blog post:[Analysis of the Boston Housing Prices Dataset](https://rpubs.com/joelrudinas03/BostonHousingPrices) by Joel Jr Ffc Rudinas in R which uses a mixed correlation matrix to quickly investigate relationships between the variables. After looking for ways to do this in Python, I settled on the correlation heatmap using Seaborn:
#
# - **Positive Correlation**: both variables change in the same direction (light color).
#
# - **Neutral Correlation**: No relationship in the change of the variables.
#
# - **Negative Correlation**: variables change in opposite directions (dark color).

# %%
# using a correlation heatmap, we can quickly get a sense for any relationships between the dataset. The darkest and lightest squares show variables which have a strong relationship. 
plt.figure(figsize=(15, 10))
cmap=sns.cubehelix_palette(50, light=0.95, dark=0.15)

# rounding to 2 decimal places and increasing the font size
sns.heatmap(data=boston.corr().round(2), annot=True, annot_kws={"size":14})
#plt.tight_layout()

#save the plot
plt.savefig('plots/bostondatasetcorrelation.png')

# show plot
plt.show()

# %% [markdown]
# From the correlation heatmap
#
# - We can see a positive correlation between MEDV and RM at 0.69. When the average number of rooms increase the price of the house also increases.
# - Negative correlation between MEDV and LSTAT (% lower status of the population): -0.76
# - Negative correlation between MEDV and PTRatio (pupil-teacher ratio by town): (-0.52)
# - Negative correlation between MEDV and INDUS (proportion of non-retail business acres per town) (-0.6)
#
# Let's plot these to see more details:

# %%
sns.set(style="whitegrid",  rc={'figure.figsize':(11.7,8.27)})

df= boston[['RM','LSTAT','CRIM','INDUS','PTRATIO', 'MEDV']]

#create a folder to add the plots to
if not os.path.exists("plots/linearregression/"):
    os.makedirs("plots/linearregression/")

# random color from palette for each plot    
import random
df_color = sns.color_palette("husl")
random.choice(df_color)    
    
@interact
def scatter_plot(feature=list(df.select_dtypes('number').columns)):
    
    for i, col in enumerate(df):
       sns.regplot(x=feature, y='MEDV', data=df, color=random.choice(df_color))
       plt.savefig("plots/linearregression/linearreg_" + str(i) + ".png")
# Out:
# interactive(children=(Dropdown(description='feature', options=('RM', 'LSTAT', 'CRIM', 'INDUS', 'PTRATIO', 'MED…

# %%
sns.set(style="whitegrid", palette="BuGn_r", rc={'figure.figsize':(11.7,8.27)})

#sns.scatterplot(x='RM', y='MEDV', data=boston)
sns.regplot(x='RM', y='MEDV', data=boston)
title="Plotting the relationship between MEDV and RM"

# Set x-axis label
plt.xlabel('Average number of rooms')
# Set y-axis label
plt.ylabel('Median value (in 1000s)')

# increasing font size
plt.title(title, fontsize=16)

#save the plot
plt.savefig('plots/medvvrmrelationship.png')

# Show the plot
plt.show()

# %% [markdown]
# From the correlation heatmap, we can we a negative correlation between MEDV and LSTAT at -0.74. When the % of lower status of the populations increases the value of houses decrease.

# %%
sns.set(style="whitegrid", palette="BuGn_r", rc={'figure.figsize':(11.7,8.27)})


sns.regplot(x='LSTAT', y='MEDV', data=boston)
title="Plotting the relationship between MEDV and LSTAT"

# increasing font size
plt.title(title, fontsize=16)

# Set x-axis label
plt.xlabel('% lower status of the population')
# Set y-axis label
plt.ylabel('Median value of owner-occupied homes')

#save the plot
plt.savefig('plots/medvandlstatrelationship.png')

# Show the plot
plt.show()

# %% [markdown]
# # Part 2. Inferential Statistics

# %% [markdown]
# Use inferential statistics to analyse whether there is a significant difference in median house prices between houses that are along the Charles river and those that aren’t.

# %%
# Gettin summary statistics of MEDV for the population
rp.summary_cont(boston['MEDV'])
# Out:
#   Variable      N          Mean           SD          SE     95% Conf.  \
# 0     MEDV  490.0  21635.918367  7865.301063  355.318083  20937.779775
#
#       Interval
# 0  22334.05696

# %%
# let's look at the data grouped by whether they bound the River or otherwise.
rp.summary_cont(boston['MEDV'].groupby(boston['CHAS']))
# Out:
#         N          Mean           SD           SE     95% Conf.      Interval
# CHAS
# 0.0   461  21488.503254  7898.848164   367.886036  20766.663292  22210.343215
# 1.0    29  23979.310345  7024.161328  1304.354013  21377.524579  26581.096111

# %% [markdown]
# From the above summary we can see that the houses bound the river have a higher mean MEDV. Let's visualise this with a boxplot.

# %%
sns.set(style="whitegrid", palette="husl", rc={'figure.figsize':(11.7,8.27)})

sns.catplot(x='CHAS', y='MEDV', kind="box", data=boston)

title="Boxplot of the house prices"

# increasing font size
plt.title(title, fontsize=16)

#save the plot
plt.savefig('plots/boxplot.png')

plt.show()

# %%
riverhouse_df = boston[boston['CHAS']==1.0]
other_df = boston[boston['CHAS']==0.0]

# %%
import matplotlib.pyplot as plt
3
title="House prices"

# increasing font size
plt.title(title, fontsize=16)

plt.hist(other_df['MEDV'], label='Not River Bound')
plt.hist(riverhouse_df['MEDV'], label='Charles River houses')

# Set x-axis label
plt.xlabel('MEDV (Price)')
# Set y-axis label
plt.ylabel('Frequency')


plt.legend()

plt.savefig('plots/hist.png')

plt.show()

# %%
#add info about the One way Anova

# %%
#oneway anova
import scipy.stats as stats
stats.f_oneway(other_df['MEDV'], riverhouse_df['MEDV'])
# Out:
# F_onewayResult(statistic=2.7459981221672622, pvalue=0.098140893200901)

# %% [markdown]
# Check which dataset has the highest mean the population or the sample?

# %%
Mean1 = other_df.MEDV.mean()
Mean2 = riverhouse_df.MEDV.mean()
print("Mean price Boston house dataset (population):", Mean1)
print("mean price Charles river House (sample):", Mean2)
# Out:
# Mean price Boston house dataset (population): 21488.503253796094
# mean price Charles river House (sample): 23979.310344827587

# %% [markdown]
# ### Z-test

# %% [markdown]
# Comparing the mean of the house not by the river (22.09) and river bound (28.44) looks much bigger however we can use a Z-TEST to check if it is statistically significant. We use use a z-test when the sample is greater than 30 and riverhouse_df has 35.

# %%
# Convert into two arrays
X2 = np.array(other_df.MEDV)
Y2 = np.array(riverhouse_df.MEDV)

# %%
# import the package for performing Z Test
from statsmodels.stats.weightstats import ztest

# %%
ztest(Y2,x2=None,value=Mean1)
# Out:
# (1.9096097115736, 0.056183483767629605)

# %% [markdown]
# p value is 0.0014868133390002274 which is lower than 0.05 and therefore is statistically significant.

# %% [markdown]
# # 3. Predict
#
# Use keras to create a neural network that can predict the median house price based on the other variables in the dataset.
#
# The target variable, 'MEDV', will be the variable we seek to predict.
#
# https://towardsdatascience.com/how-do-we-train-neural-networks-edd985562b73
#
# https://towardsdatascience.com/building-a-deep-learning-model-using-keras-1548ca149d37
#
# https://tensorflow.rstudio.com/keras/articles/tutorial_basic_regression.html
# https://cran.r-project.org/web/packages/keras/vignettes/getting_started.html

# %%
# first neural network with keras tutorial
#importing libraries
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# The first thing to get right is to ensure the input layer has the right number of input features. I will only take what I consider the interesting features which had a strong correlation with MEDV.

# %%
#input features (X) 
#inputs = boston.iloc[:, 0:13]
# only take the features that have a strong correlation of MEDV
features = boston[['RM', 'LSTAT', 'PTRATIO', 'INDUS']]
#train_X = boston.drop(columns=['MEDV'])
# What we want to predict
#train_y = boston.iloc[:,13]
prices = boston[['MEDV']]

# %% [markdown]
# ### Normalising the data
# A best practices I came across when researching Neural Networks was to normalise the data to see better results.

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
#features= pd.DataFrame(scaler.fit_transform(features), columns=features.columns)
features= scaler.fit_transform(features)
prices= prices.values.reshape(-1,1)
#prices = pd.DataFrame(scaler.fit_transform(prices), columns=prices.columns)
prices = scaler.fit_transform(prices)

# %% [markdown]
# ### Create train and test split

# %%
from sklearn.model_selection import train_test_split

# Shuffle and split the data into training and testing subsets
X_train, X_test, y_train, y_test = train_test_split(features, prices, test_size=0.33, random_state=10)

# Success
print("Training and testing split was successful.")
# Out:
# Training and testing split was successful.

# %%
# checking, it should be divided in to 80% train, 20% test
print(features.shape[0])
print("Train:", float(X_train.shape[0]) / float(features.shape[0]))
print("Test:", float(X_test.shape[0]) / float(features.shape[0]))
# Out:
# 490
# Train: 0.6693877551020408
# Test: 0.3306122448979592

# %% [markdown]
# As this a regression problem, the loss function we use is mean squared error and the metrics against which we evaluate the performance of the model is mean absolute error and accuracy. Also the output layer should be linear also.

# %%
from keras.callbacks import ModelCheckpoint
m = kr.models.Sequential()

n_cols = X_train.shape[1]
# The Input Layer :
m.add(kr.layers.Dense(128, kernel_initializer='normal',input_shape=(n_cols,), activation='relu'))
# The Hidden Layers :
m.add(kr.layers.Dense(256, kernel_initializer='normal',activation='relu'))

m.add(kr.layers.Dense(128, kernel_initializer='normal',activation='relu'))

# The Output Layer :
m.add(kr.layers.Dense(1, kernel_initializer='normal',activation='linear'))


# Compile the network :
m.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error', 'accuracy'])
print(m.summary())

# checkpoint
filepath="weights.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

hist = m.fit(X_train, y_train, epochs=100, batch_size=6, validation_data=(X_test,y_test), callbacks=callbacks_list)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 128)               640
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 66,689
# Trainable params: 66,689
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 328 samples, validate on 162 samples
# Epoch 1/100
# 328/328 [==============================] - 1s 4ms/step - loss: 0.1722 - mean_absolute_error: 0.1722 - accuracy: 0.0030 - val_loss: 0.0815 - val_mean_absolute_error: 0.0815 - val_accuracy: 0.0062
#
# Epoch 00001: val_accuracy improved from -inf to 0.00617, saving model to weights.best.hdf5
# Epoch 2/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0736 - mean_absolute_error: 0.0736 - accuracy: 0.0061 - val_loss: 0.0685 - val_mean_absolute_error: 0.0685 - val_accuracy: 0.0062
#
# Epoch 00002: val_accuracy did not improve from 0.00617
# Epoch 3/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0698 - mean_absolute_error: 0.0698 - accuracy: 0.0061 - val_loss: 0.0598 - val_mean_absolute_error: 0.0598 - val_accuracy: 0.0062
#
# Epoch 00003: val_accuracy did not improve from 0.00617
# Epoch 4/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0716 - mean_absolute_error: 0.0716 - accuracy: 0.0061 - val_loss: 0.0602 - val_mean_absolute_error: 0.0602 - val_accuracy: 0.0062
#
# Epoch 00004: val_accuracy did not improve from 0.00617
# Epoch 5/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0671 - mean_absolute_error: 0.0671 - accuracy: 0.0061 - val_loss: 0.0668 - val_mean_absolute_error: 0.0668 - val_accuracy: 0.0062
#
# Epoch 00005: val_accuracy did not improve from 0.00617
# Epoch 6/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0765 - mean_absolute_error: 0.0765 - accuracy: 0.0061 - val_loss: 0.0586 - val_mean_absolute_error: 0.0586 - val_accuracy: 0.0062
#
# Epoch 00006: val_accuracy did not improve from 0.00617
# Epoch 7/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0705 - mean_absolute_error: 0.0705 - accuracy: 0.0061 - val_loss: 0.0661 - val_mean_absolute_error: 0.0661 - val_accuracy: 0.0062
#
# Epoch 00007: val_accuracy did not improve from 0.00617
# Epoch 8/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0742 - mean_absolute_error: 0.0742 - accuracy: 0.0061 - val_loss: 0.0600 - val_mean_absolute_error: 0.0600 - val_accuracy: 0.0062
#
# Epoch 00008: val_accuracy did not improve from 0.00617
# Epoch 9/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0665 - mean_absolute_error: 0.0665 - accuracy: 0.0061 - val_loss: 0.0548 - val_mean_absolute_error: 0.0548 - val_accuracy: 0.0062
#
# Epoch 00009: val_accuracy did not improve from 0.00617
# Epoch 10/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0656 - mean_absolute_error: 0.0656 - accuracy: 0.0061 - val_loss: 0.0790 - val_mean_absolute_error: 0.0790 - val_accuracy: 0.0062
#
# Epoch 00010: val_accuracy did not improve from 0.00617
# Epoch 11/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0667 - mean_absolute_error: 0.0667 - accuracy: 0.0061 - val_loss: 0.0615 - val_mean_absolute_error: 0.0615 - val_accuracy: 0.0062
#
# Epoch 00011: val_accuracy did not improve from 0.00617
# Epoch 12/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0629 - mean_absolute_error: 0.0629 - accuracy: 0.0061 - val_loss: 0.0620 - val_mean_absolute_error: 0.0620 - val_accuracy: 0.0062
#
# Epoch 00012: val_accuracy did not improve from 0.00617
# Epoch 13/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0651 - mean_absolute_error: 0.0651 - accuracy: 0.0061 - val_loss: 0.0615 - val_mean_absolute_error: 0.0615 - val_accuracy: 0.0062
#
# Epoch 00013: val_accuracy did not improve from 0.00617
# Epoch 14/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0662 - mean_absolute_error: 0.0662 - accuracy: 0.0061 - val_loss: 0.0593 - val_mean_absolute_error: 0.0593 - val_accuracy: 0.0062
#
# Epoch 00014: val_accuracy did not improve from 0.00617
# Epoch 15/100
# 328/328 [==============================] - 0s 993us/step - loss: 0.0680 - mean_absolute_error: 0.0680 - accuracy: 0.0061 - val_loss: 0.0546 - val_mean_absolute_error: 0.0546 - val_accuracy: 0.0062
#
# Epoch 00015: val_accuracy did not improve from 0.00617
# Epoch 16/100
# 328/328 [==============================] - 0s 969us/step - loss: 0.0640 - mean_absolute_error: 0.0640 - accuracy: 0.0061 - val_loss: 0.0540 - val_mean_absolute_error: 0.0540 - val_accuracy: 0.0062
#
# Epoch 00016: val_accuracy did not improve from 0.00617
# Epoch 17/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0619 - mean_absolute_error: 0.0619 - accuracy: 0.0061 - val_loss: 0.0587 - val_mean_absolute_error: 0.0587 - val_accuracy: 0.0062
#
# Epoch 00017: val_accuracy did not improve from 0.00617
# Epoch 18/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0618 - mean_absolute_error: 0.0618 - accuracy: 0.0061 - val_loss: 0.0748 - val_mean_absolute_error: 0.0748 - val_accuracy: 0.0062
#
# Epoch 00018: val_accuracy did not improve from 0.00617
# Epoch 19/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0643 - mean_absolute_error: 0.0643 - accuracy: 0.0061 - val_loss: 0.0546 - val_mean_absolute_error: 0.0546 - val_accuracy: 0.0062
#
# Epoch 00019: val_accuracy did not improve from 0.00617
# Epoch 20/100
# 328/328 [==============================] - 0s 983us/step - loss: 0.0632 - mean_absolute_error: 0.0632 - accuracy: 0.0061 - val_loss: 0.0544 - val_mean_absolute_error: 0.0544 - val_accuracy: 0.0062
#
# Epoch 00020: val_accuracy did not improve from 0.00617
# Epoch 21/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0622 - mean_absolute_error: 0.0622 - accuracy: 0.0061 - val_loss: 0.0636 - val_mean_absolute_error: 0.0636 - val_accuracy: 0.0062
#
# Epoch 00021: val_accuracy did not improve from 0.00617
# Epoch 22/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0650 - mean_absolute_error: 0.0650 - accuracy: 0.0061 - val_loss: 0.0687 - val_mean_absolute_error: 0.0687 - val_accuracy: 0.0062
#
# Epoch 00022: val_accuracy did not improve from 0.00617
# Epoch 23/100
# 328/328 [==============================] - 0s 992us/step - loss: 0.0639 - mean_absolute_error: 0.0639 - accuracy: 0.0061 - val_loss: 0.0596 - val_mean_absolute_error: 0.0596 - val_accuracy: 0.0062
#
# Epoch 00023: val_accuracy did not improve from 0.00617
# Epoch 24/100
# 328/328 [==============================] - 0s 982us/step - loss: 0.0638 - mean_absolute_error: 0.0638 - accuracy: 0.0061 - val_loss: 0.0539 - val_mean_absolute_error: 0.0539 - val_accuracy: 0.0062
#
# Epoch 00024: val_accuracy did not improve from 0.00617
# Epoch 25/100
# 328/328 [==============================] - 0s 974us/step - loss: 0.0603 - mean_absolute_error: 0.0603 - accuracy: 0.0061 - val_loss: 0.0564 - val_mean_absolute_error: 0.0564 - val_accuracy: 0.0062
#
# Epoch 00025: val_accuracy did not improve from 0.00617
# Epoch 26/100
# 328/328 [==============================] - 0s 994us/step - loss: 0.0642 - mean_absolute_error: 0.0642 - accuracy: 0.0061 - val_loss: 0.0560 - val_mean_absolute_error: 0.0560 - val_accuracy: 0.0062
#
# Epoch 00026: val_accuracy did not improve from 0.00617
# Epoch 27/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0608 - mean_absolute_error: 0.0608 - accuracy: 0.0061 - val_loss: 0.0535 - val_mean_absolute_error: 0.0535 - val_accuracy: 0.0062
#
# Epoch 00027: val_accuracy did not improve from 0.00617
# Epoch 28/100
# 328/328 [==============================] - 0s 972us/step - loss: 0.0599 - mean_absolute_error: 0.0599 - accuracy: 0.0061 - val_loss: 0.0523 - val_mean_absolute_error: 0.0523 - val_accuracy: 0.0062
#
# Epoch 00028: val_accuracy did not improve from 0.00617
# Epoch 29/100
# 328/328 [==============================] - 0s 987us/step - loss: 0.0644 - mean_absolute_error: 0.0644 - accuracy: 0.0061 - val_loss: 0.0542 - val_mean_absolute_error: 0.0542 - val_accuracy: 0.0062
#
# Epoch 00029: val_accuracy did not improve from 0.00617
# Epoch 30/100
# 328/328 [==============================] - 0s 982us/step - loss: 0.0635 - mean_absolute_error: 0.0635 - accuracy: 0.0061 - val_loss: 0.0571 - val_mean_absolute_error: 0.0571 - val_accuracy: 0.0062
#
# Epoch 00030: val_accuracy did not improve from 0.00617
# Epoch 31/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0616 - mean_absolute_error: 0.0616 - accuracy: 0.0061 - val_loss: 0.0543 - val_mean_absolute_error: 0.0543 - val_accuracy: 0.0062
#
# Epoch 00031: val_accuracy did not improve from 0.00617
# Epoch 32/100
# 328/328 [==============================] - 0s 996us/step - loss: 0.0638 - mean_absolute_error: 0.0638 - accuracy: 0.0061 - val_loss: 0.0509 - val_mean_absolute_error: 0.0509 - val_accuracy: 0.0062
#
# Epoch 00032: val_accuracy did not improve from 0.00617
# Epoch 33/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0597 - mean_absolute_error: 0.0597 - accuracy: 0.0061 - val_loss: 0.0561 - val_mean_absolute_error: 0.0561 - val_accuracy: 0.0062
#
# Epoch 00033: val_accuracy did not improve from 0.00617
# Epoch 34/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0593 - mean_absolute_error: 0.0593 - accuracy: 0.0061 - val_loss: 0.0593 - val_mean_absolute_error: 0.0593 - val_accuracy: 0.0062
#
# Epoch 00034: val_accuracy did not improve from 0.00617
# Epoch 35/100
# 328/328 [==============================] - 0s 992us/step - loss: 0.0606 - mean_absolute_error: 0.0606 - accuracy: 0.0061 - val_loss: 0.0533 - val_mean_absolute_error: 0.0533 - val_accuracy: 0.0062
#
# Epoch 00035: val_accuracy did not improve from 0.00617
# Epoch 36/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0602 - mean_absolute_error: 0.0602 - accuracy: 0.0061 - val_loss: 0.0659 - val_mean_absolute_error: 0.0659 - val_accuracy: 0.0062
#
# Epoch 00036: val_accuracy did not improve from 0.00617
# Epoch 37/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0625 - mean_absolute_error: 0.0625 - accuracy: 0.0061 - val_loss: 0.0570 - val_mean_absolute_error: 0.0570 - val_accuracy: 0.0062
#
# Epoch 00037: val_accuracy did not improve from 0.00617
# Epoch 38/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0583 - mean_absolute_error: 0.0583 - accuracy: 0.0061 - val_loss: 0.0544 - val_mean_absolute_error: 0.0544 - val_accuracy: 0.0062
#
# Epoch 00038: val_accuracy did not improve from 0.00617
# Epoch 39/100
# 328/328 [==============================] - 0s 993us/step - loss: 0.0591 - mean_absolute_error: 0.0591 - accuracy: 0.0061 - val_loss: 0.0552 - val_mean_absolute_error: 0.0552 - val_accuracy: 0.0062
#
# Epoch 00039: val_accuracy did not improve from 0.00617
# Epoch 40/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0594 - mean_absolute_error: 0.0594 - accuracy: 0.0061 - val_loss: 0.0628 - val_mean_absolute_error: 0.0628 - val_accuracy: 0.0062
#
# Epoch 00040: val_accuracy did not improve from 0.00617
# Epoch 41/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0593 - mean_absolute_error: 0.0593 - accuracy: 0.0061 - val_loss: 0.0509 - val_mean_absolute_error: 0.0509 - val_accuracy: 0.0062
#
# Epoch 00041: val_accuracy did not improve from 0.00617
# Epoch 42/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0587 - mean_absolute_error: 0.0587 - accuracy: 0.0061 - val_loss: 0.0548 - val_mean_absolute_error: 0.0548 - val_accuracy: 0.0062
#
# Epoch 00042: val_accuracy did not improve from 0.00617
# Epoch 43/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0586 - mean_absolute_error: 0.0586 - accuracy: 0.0061 - val_loss: 0.0567 - val_mean_absolute_error: 0.0567 - val_accuracy: 0.0062
#
# Epoch 00043: val_accuracy did not improve from 0.00617
# Epoch 44/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0560 - mean_absolute_error: 0.0560 - accuracy: 0.0061 - val_loss: 0.0509 - val_mean_absolute_error: 0.0509 - val_accuracy: 0.0062
#
# Epoch 00044: val_accuracy did not improve from 0.00617
# Epoch 45/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0641 - mean_absolute_error: 0.0641 - accuracy: 0.0061 - val_loss: 0.0530 - val_mean_absolute_error: 0.0530 - val_accuracy: 0.0062
#
# Epoch 00045: val_accuracy did not improve from 0.00617
# Epoch 46/100
# 328/328 [==============================] - 0s 993us/step - loss: 0.0621 - mean_absolute_error: 0.0621 - accuracy: 0.0061 - val_loss: 0.0564 - val_mean_absolute_error: 0.0564 - val_accuracy: 0.0062
#
# Epoch 00046: val_accuracy did not improve from 0.00617
# Epoch 47/100
# 328/328 [==============================] - 0s 983us/step - loss: 0.0587 - mean_absolute_error: 0.0587 - accuracy: 0.0061 - val_loss: 0.0545 - val_mean_absolute_error: 0.0545 - val_accuracy: 0.0062
#
# Epoch 00047: val_accuracy did not improve from 0.00617
# Epoch 48/100
# 328/328 [==============================] - 0s 986us/step - loss: 0.0631 - mean_absolute_error: 0.0631 - accuracy: 0.0061 - val_loss: 0.0541 - val_mean_absolute_error: 0.0541 - val_accuracy: 0.0062
#
# Epoch 00048: val_accuracy did not improve from 0.00617
# Epoch 49/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0564 - mean_absolute_error: 0.0564 - accuracy: 0.0061 - val_loss: 0.0520 - val_mean_absolute_error: 0.0520 - val_accuracy: 0.0062
#
# Epoch 00049: val_accuracy did not improve from 0.00617
# Epoch 50/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0595 - mean_absolute_error: 0.0595 - accuracy: 0.0061 - val_loss: 0.0548 - val_mean_absolute_error: 0.0548 - val_accuracy: 0.0062
#
# Epoch 00050: val_accuracy did not improve from 0.00617
# Epoch 51/100
# 328/328 [==============================] - 0s 969us/step - loss: 0.0559 - mean_absolute_error: 0.0559 - accuracy: 0.0061 - val_loss: 0.0520 - val_mean_absolute_error: 0.0520 - val_accuracy: 0.0062
#
# Epoch 00051: val_accuracy did not improve from 0.00617
# Epoch 52/100
# 328/328 [==============================] - 0s 976us/step - loss: 0.0566 - mean_absolute_error: 0.0566 - accuracy: 0.0061 - val_loss: 0.0531 - val_mean_absolute_error: 0.0531 - val_accuracy: 0.0062
#
# Epoch 00052: val_accuracy did not improve from 0.00617
# Epoch 53/100
# 328/328 [==============================] - 0s 982us/step - loss: 0.0565 - mean_absolute_error: 0.0565 - accuracy: 0.0061 - val_loss: 0.0588 - val_mean_absolute_error: 0.0588 - val_accuracy: 0.0062
#
# Epoch 00053: val_accuracy did not improve from 0.00617
# Epoch 54/100
# 328/328 [==============================] - 0s 990us/step - loss: 0.0559 - mean_absolute_error: 0.0559 - accuracy: 0.0061 - val_loss: 0.0503 - val_mean_absolute_error: 0.0503 - val_accuracy: 0.0062
#
# Epoch 00054: val_accuracy did not improve from 0.00617
# Epoch 55/100
# 328/328 [==============================] - 0s 976us/step - loss: 0.0552 - mean_absolute_error: 0.0552 - accuracy: 0.0061 - val_loss: 0.0511 - val_mean_absolute_error: 0.0511 - val_accuracy: 0.0062
#
# Epoch 00055: val_accuracy did not improve from 0.00617
# Epoch 56/100
# 328/328 [==============================] - 0s 980us/step - loss: 0.0543 - mean_absolute_error: 0.0543 - accuracy: 0.0061 - val_loss: 0.0522 - val_mean_absolute_error: 0.0522 - val_accuracy: 0.0062
#
# Epoch 00056: val_accuracy did not improve from 0.00617
# Epoch 57/100
# 328/328 [==============================] - 0s 966us/step - loss: 0.0583 - mean_absolute_error: 0.0583 - accuracy: 0.0061 - val_loss: 0.0528 - val_mean_absolute_error: 0.0528 - val_accuracy: 0.0062
#
# Epoch 00057: val_accuracy did not improve from 0.00617
# Epoch 58/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0560 - mean_absolute_error: 0.0560 - accuracy: 0.0061 - val_loss: 0.0568 - val_mean_absolute_error: 0.0568 - val_accuracy: 0.0062
#
# Epoch 00058: val_accuracy did not improve from 0.00617
# Epoch 59/100
# 328/328 [==============================] - 0s 980us/step - loss: 0.0576 - mean_absolute_error: 0.0576 - accuracy: 0.0061 - val_loss: 0.0545 - val_mean_absolute_error: 0.0545 - val_accuracy: 0.0062
#
# Epoch 00059: val_accuracy did not improve from 0.00617
# Epoch 60/100
# 328/328 [==============================] - 0s 985us/step - loss: 0.0591 - mean_absolute_error: 0.0591 - accuracy: 0.0061 - val_loss: 0.0481 - val_mean_absolute_error: 0.0481 - val_accuracy: 0.0062
#
# Epoch 00060: val_accuracy did not improve from 0.00617
# Epoch 61/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0543 - mean_absolute_error: 0.0543 - accuracy: 0.0061 - val_loss: 0.0575 - val_mean_absolute_error: 0.0575 - val_accuracy: 0.0062
#
# Epoch 00061: val_accuracy did not improve from 0.00617
# Epoch 62/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0587 - mean_absolute_error: 0.0587 - accuracy: 0.0061 - val_loss: 0.0560 - val_mean_absolute_error: 0.0560 - val_accuracy: 0.0062
#
# Epoch 00062: val_accuracy did not improve from 0.00617
# Epoch 63/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0552 - mean_absolute_error: 0.0552 - accuracy: 0.0061 - val_loss: 0.0514 - val_mean_absolute_error: 0.0514 - val_accuracy: 0.0062
#
# Epoch 00063: val_accuracy did not improve from 0.00617
# Epoch 64/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0533 - mean_absolute_error: 0.0533 - accuracy: 0.0061 - val_loss: 0.0522 - val_mean_absolute_error: 0.0522 - val_accuracy: 0.0062
#
# Epoch 00064: val_accuracy did not improve from 0.00617
# Epoch 65/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0543 - mean_absolute_error: 0.0543 - accuracy: 0.0061 - val_loss: 0.0519 - val_mean_absolute_error: 0.0519 - val_accuracy: 0.0062
#
# Epoch 00065: val_accuracy did not improve from 0.00617
# Epoch 66/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0570 - mean_absolute_error: 0.0570 - accuracy: 0.0061 - val_loss: 0.0605 - val_mean_absolute_error: 0.0605 - val_accuracy: 0.0062
#
# Epoch 00066: val_accuracy did not improve from 0.00617
# Epoch 67/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0557 - mean_absolute_error: 0.0557 - accuracy: 0.0061 - val_loss: 0.0518 - val_mean_absolute_error: 0.0518 - val_accuracy: 0.0062
#
# Epoch 00067: val_accuracy did not improve from 0.00617
# Epoch 68/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0519 - mean_absolute_error: 0.0519 - accuracy: 0.0061 - val_loss: 0.0489 - val_mean_absolute_error: 0.0489 - val_accuracy: 0.0062
#
# Epoch 00068: val_accuracy did not improve from 0.00617
# Epoch 69/100
# 328/328 [==============================] - 0s 976us/step - loss: 0.0555 - mean_absolute_error: 0.0555 - accuracy: 0.0061 - val_loss: 0.0570 - val_mean_absolute_error: 0.0570 - val_accuracy: 0.0062
#
# Epoch 00069: val_accuracy did not improve from 0.00617
# Epoch 70/100
# 328/328 [==============================] - 0s 970us/step - loss: 0.0559 - mean_absolute_error: 0.0559 - accuracy: 0.0061 - val_loss: 0.0494 - val_mean_absolute_error: 0.0494 - val_accuracy: 0.0062
#
# Epoch 00070: val_accuracy did not improve from 0.00617
# Epoch 71/100
# 328/328 [==============================] - 0s 974us/step - loss: 0.0555 - mean_absolute_error: 0.0555 - accuracy: 0.0061 - val_loss: 0.0506 - val_mean_absolute_error: 0.0506 - val_accuracy: 0.0062
#
# Epoch 00071: val_accuracy did not improve from 0.00617
# Epoch 72/100
# 328/328 [==============================] - 0s 969us/step - loss: 0.0526 - mean_absolute_error: 0.0526 - accuracy: 0.0061 - val_loss: 0.0504 - val_mean_absolute_error: 0.0504 - val_accuracy: 0.0062
#
# Epoch 00072: val_accuracy did not improve from 0.00617
# Epoch 73/100
# 328/328 [==============================] - 0s 969us/step - loss: 0.0536 - mean_absolute_error: 0.0536 - accuracy: 0.0061 - val_loss: 0.0569 - val_mean_absolute_error: 0.0569 - val_accuracy: 0.0062
#
# Epoch 00073: val_accuracy did not improve from 0.00617
# Epoch 74/100
# 328/328 [==============================] - 0s 973us/step - loss: 0.0577 - mean_absolute_error: 0.0577 - accuracy: 0.0061 - val_loss: 0.0504 - val_mean_absolute_error: 0.0504 - val_accuracy: 0.0062
#
# Epoch 00074: val_accuracy did not improve from 0.00617
# Epoch 75/100
# 328/328 [==============================] - 0s 974us/step - loss: 0.0534 - mean_absolute_error: 0.0534 - accuracy: 0.0061 - val_loss: 0.0509 - val_mean_absolute_error: 0.0509 - val_accuracy: 0.0062
#
# Epoch 00075: val_accuracy did not improve from 0.00617
# Epoch 76/100
# 328/328 [==============================] - 0s 970us/step - loss: 0.0535 - mean_absolute_error: 0.0535 - accuracy: 0.0061 - val_loss: 0.0490 - val_mean_absolute_error: 0.0490 - val_accuracy: 0.0062
#
# Epoch 00076: val_accuracy did not improve from 0.00617
# Epoch 77/100
# 328/328 [==============================] - 0s 980us/step - loss: 0.0518 - mean_absolute_error: 0.0518 - accuracy: 0.0061 - val_loss: 0.0530 - val_mean_absolute_error: 0.0530 - val_accuracy: 0.0062
#
# Epoch 00077: val_accuracy did not improve from 0.00617
# Epoch 78/100
# 328/328 [==============================] - 0s 967us/step - loss: 0.0525 - mean_absolute_error: 0.0525 - accuracy: 0.0061 - val_loss: 0.0499 - val_mean_absolute_error: 0.0499 - val_accuracy: 0.0062
#
# Epoch 00078: val_accuracy did not improve from 0.00617
# Epoch 79/100
# 328/328 [==============================] - 0s 961us/step - loss: 0.0530 - mean_absolute_error: 0.0530 - accuracy: 0.0061 - val_loss: 0.0510 - val_mean_absolute_error: 0.0510 - val_accuracy: 0.0062
#
# Epoch 00079: val_accuracy did not improve from 0.00617
# Epoch 80/100
# 328/328 [==============================] - 0s 971us/step - loss: 0.0521 - mean_absolute_error: 0.0521 - accuracy: 0.0061 - val_loss: 0.0508 - val_mean_absolute_error: 0.0508 - val_accuracy: 0.0062
#
# Epoch 00080: val_accuracy did not improve from 0.00617
# Epoch 81/100
# 328/328 [==============================] - 0s 971us/step - loss: 0.0534 - mean_absolute_error: 0.0534 - accuracy: 0.0061 - val_loss: 0.0533 - val_mean_absolute_error: 0.0533 - val_accuracy: 0.0062
#
# Epoch 00081: val_accuracy did not improve from 0.00617
# Epoch 82/100
# 328/328 [==============================] - 0s 966us/step - loss: 0.0533 - mean_absolute_error: 0.0533 - accuracy: 0.0061 - val_loss: 0.0524 - val_mean_absolute_error: 0.0524 - val_accuracy: 0.0062
#
# Epoch 00082: val_accuracy did not improve from 0.00617
# Epoch 83/100
# 328/328 [==============================] - 0s 977us/step - loss: 0.0536 - mean_absolute_error: 0.0536 - accuracy: 0.0061 - val_loss: 0.0695 - val_mean_absolute_error: 0.0695 - val_accuracy: 0.0062
#
# Epoch 00083: val_accuracy did not improve from 0.00617
# Epoch 84/100
# 328/328 [==============================] - 0s 968us/step - loss: 0.0550 - mean_absolute_error: 0.0550 - accuracy: 0.0061 - val_loss: 0.0507 - val_mean_absolute_error: 0.0507 - val_accuracy: 0.0062
#
# Epoch 00084: val_accuracy did not improve from 0.00617
# Epoch 85/100
# 328/328 [==============================] - 0s 961us/step - loss: 0.0531 - mean_absolute_error: 0.0531 - accuracy: 0.0061 - val_loss: 0.0506 - val_mean_absolute_error: 0.0506 - val_accuracy: 0.0062
#
# Epoch 00085: val_accuracy did not improve from 0.00617
# Epoch 86/100
# 328/328 [==============================] - 0s 972us/step - loss: 0.0552 - mean_absolute_error: 0.0552 - accuracy: 0.0061 - val_loss: 0.0488 - val_mean_absolute_error: 0.0488 - val_accuracy: 0.0062
#
# Epoch 00086: val_accuracy did not improve from 0.00617
# Epoch 87/100
# 328/328 [==============================] - 0s 984us/step - loss: 0.0517 - mean_absolute_error: 0.0517 - accuracy: 0.0061 - val_loss: 0.0542 - val_mean_absolute_error: 0.0542 - val_accuracy: 0.0062
#
# Epoch 00087: val_accuracy did not improve from 0.00617
# Epoch 88/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0526 - mean_absolute_error: 0.0526 - accuracy: 0.0061 - val_loss: 0.0505 - val_mean_absolute_error: 0.0505 - val_accuracy: 0.0062
#
# Epoch 00088: val_accuracy did not improve from 0.00617
# Epoch 89/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0537 - mean_absolute_error: 0.0537 - accuracy: 0.0061 - val_loss: 0.0546 - val_mean_absolute_error: 0.0546 - val_accuracy: 0.0062
#
# Epoch 00089: val_accuracy did not improve from 0.00617
# Epoch 90/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0532 - mean_absolute_error: 0.0532 - accuracy: 0.0061 - val_loss: 0.0496 - val_mean_absolute_error: 0.0496 - val_accuracy: 0.0062
#
# Epoch 00090: val_accuracy did not improve from 0.00617
# Epoch 91/100
# 328/328 [==============================] - 0s 971us/step - loss: 0.0517 - mean_absolute_error: 0.0517 - accuracy: 0.0061 - val_loss: 0.0532 - val_mean_absolute_error: 0.0532 - val_accuracy: 0.0062
#
# Epoch 00091: val_accuracy did not improve from 0.00617
# Epoch 92/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0528 - mean_absolute_error: 0.0528 - accuracy: 0.0061 - val_loss: 0.0496 - val_mean_absolute_error: 0.0496 - val_accuracy: 0.0062
#
# Epoch 00092: val_accuracy did not improve from 0.00617
# Epoch 93/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0559 - mean_absolute_error: 0.0559 - accuracy: 0.0061 - val_loss: 0.0497 - val_mean_absolute_error: 0.0497 - val_accuracy: 0.0062
#
# Epoch 00093: val_accuracy did not improve from 0.00617
# Epoch 94/100
# 328/328 [==============================] - 0s 980us/step - loss: 0.0523 - mean_absolute_error: 0.0523 - accuracy: 0.0061 - val_loss: 0.0494 - val_mean_absolute_error: 0.0494 - val_accuracy: 0.0062
#
# Epoch 00094: val_accuracy did not improve from 0.00617
# Epoch 95/100
# 328/328 [==============================] - 0s 993us/step - loss: 0.0524 - mean_absolute_error: 0.0524 - accuracy: 0.0061 - val_loss: 0.0492 - val_mean_absolute_error: 0.0492 - val_accuracy: 0.0062
#
# Epoch 00095: val_accuracy did not improve from 0.00617
# Epoch 96/100
# 328/328 [==============================] - 0s 996us/step - loss: 0.0523 - mean_absolute_error: 0.0523 - accuracy: 0.0061 - val_loss: 0.0508 - val_mean_absolute_error: 0.0508 - val_accuracy: 0.0062
#
# Epoch 00096: val_accuracy did not improve from 0.00617
# Epoch 97/100
# 328/328 [==============================] - 0s 975us/step - loss: 0.0576 - mean_absolute_error: 0.0576 - accuracy: 0.0061 - val_loss: 0.0496 - val_mean_absolute_error: 0.0496 - val_accuracy: 0.0062
#
# Epoch 00097: val_accuracy did not improve from 0.00617
# Epoch 98/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0528 - mean_absolute_error: 0.0528 - accuracy: 0.0061 - val_loss: 0.0503 - val_mean_absolute_error: 0.0503 - val_accuracy: 0.0062
#
# Epoch 00098: val_accuracy did not improve from 0.00617
# Epoch 99/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0516 - mean_absolute_error: 0.0516 - accuracy: 0.0061 - val_loss: 0.0575 - val_mean_absolute_error: 0.0575 - val_accuracy: 0.0062
#
# Epoch 00099: val_accuracy did not improve from 0.00617
# Epoch 100/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0529 - mean_absolute_error: 0.0529 - accuracy: 0.0061 - val_loss: 0.0538 - val_mean_absolute_error: 0.0538 - val_accuracy: 0.0062
#
# Epoch 00100: val_accuracy did not improve from 0.00617

# %%
results=m.fit(X_train,y_train)
# Out:
# Epoch 1/1
# 328/328 [==============================] - 0s 196us/step - loss: 0.0526 - mean_absolute_error: 0.0526 - accuracy: 0.0061

# %%
#print(m.metrics_names)
score = m.evaluate(X_test, y_test, verbose = 0)
print("Loss:", score[0])
print("mean_absolute_error:", score[1])
print("Test Accuracy:", score[2])
# epoch 500
# Test Score: 2214.4743403220664
# Test Accuracy: 2214.474609375

# after adding two extra hidden layers
# Test Score: 2549.8913624043366
# Test Accuracy: 2549.891357421875

# epoch 1000
# Test Score: 2241.6360710299746
# Test Accuracy: 2241.635986328125

# before normalise the data
#Test Score: 2326.835857780612
#Test Accuracy: 2326.8359375

# before increasing split from .2 to .33
#Test Score: 0.05484031901067617
#Test Accuracy: 0.0548403225839138

# before increasing split  to .33
# Test Score: 0.04884675402700165
# Test Accuracy: 0.04884675145149231
# Out:
# Loss: 0.054885676981490335
# mean_absolute_error: 0.05488567426800728
# Test Accuracy: 0.006172839552164078

# %%
# Plot training & validation accuracy values
import matplotlib.pyplot as plt
sns.set(style="whitegrid", palette="husl", rc={'figure.figsize':(11.7,8.27)})

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy', fontsize=16)

plt.ylabel('accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# Plot training & validation loss values
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss', fontsize=16)
# increasing font size
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %%
m.predict(X_test).T
# Out:
# array([[0.2291117 , 0.66640705, 0.36392698, 0.3320538 , 0.3355645 ,
#         0.44337326, 0.3846098 , 0.43977615, 0.59135944, 0.2204189 ,
#         0.48834202, 0.4676315 , 0.39247444, 0.13600698, 0.25054258,
#         0.40413532, 0.44237593, 0.3263648 , 0.22563249, 0.66328454,
#         0.35883495, 0.178507  , 0.37845472, 0.7329633 , 0.1864433 ,
#         0.4680815 , 0.35715893, 0.36375982, 0.3801667 , 0.10546196,
#         0.2935445 , 0.38301525, 0.47564223, 0.33756515, 0.34801877,
#         0.8873982 , 0.35809097, 0.32322773, 0.28991482, 0.43990847,
#         0.8407808 , 0.1921592 , 0.8890869 , 0.1611421 , 0.27653208,
#         0.14516091, 0.5553954 , 0.37654462, 0.3761224 , 0.504503  ,
#         0.2402412 , 0.347212  , 0.35324553, 0.72368824, 0.41938967,
#         0.38265806, 0.37490162, 0.34878027, 0.39242047, 0.6343419 ,
#         0.40163398, 0.7101316 , 0.8526361 , 0.3229486 , 0.3243786 ,
#         0.43854797, 0.33976737, 0.35750875, 0.37370077, 0.52322304,
#         0.21343818, 0.41890472, 0.35988244, 0.4479296 , 0.43087712,
#         0.44286343, 0.31700003, 0.08355258, 0.45938382, 0.5431434 ,
#         0.34269753, 0.35179338, 0.5322073 , 0.23225912, 0.45919937,
#         0.21820065, 0.3805199 , 0.66845125, 0.36217374, 0.21706992,
#         0.25211132, 0.37263125, 0.56837165, 0.5418487 , 0.3899092 ,
#         0.33646223, 0.4811699 , 0.22791424, 0.30175015, 0.50971866,
#         0.09964927, 0.1253224 , 0.3445031 , 0.446484  , 0.35453615,
#         0.67297953, 0.3703855 , 0.35691634, 0.5793524 , 0.29358888,
#         0.68826866, 0.3744935 , 0.14714865, 0.5116497 , 0.41203642,
#         0.73395246, 0.39754397, 0.7338392 , 0.13743809, 0.7078597 ,
#         0.543908  , 0.95277476, 0.44564322, 0.36205372, 0.09347288,
#         0.44584563, 0.61239403, 0.38461947, 0.37669542, 0.43940324,
#         0.67229384, 0.5802711 , 0.26613018, 0.14313775, 0.46423212,
#         0.55941135, 0.09230087, 0.80462736, 0.4837403 , 0.37793562,
#         0.37083152, 0.388128  , 0.35517034, 0.87355447, 0.37350956,
#         0.23379773, 0.42462808, 0.25504202, 0.41233692, 0.27781034,
#         0.31146488, 0.29533693, 0.7782896 , 0.37881652, 0.67704064,
#         0.21477571, 0.39285108, 0.21939456, 0.46710244, 0.341756  ,
#         0.08829008, 0.22906953]], dtype=float32)

# %%
y_test
# Out:
# array([[0.19178082],
#        [0.6826484 ],
#        [0.23515982],
#        [0.25342466],
#        [0.26484018],
#        [0.26255708],
#        [0.41552511],
#        [0.4109589 ],
#        [0.56849315],
#        [0.20776256],
#        [0.40639269],
#        [0.44977169],
#        [0.34931507],
#        [0.18949772],
#        [0.23744292],
#        [0.42922374],
#        [0.40182648],
#        [0.34246575],
#        [0.21232877],
#        [0.59817352],
#        [0.31050228],
#        [0.07762557],
#        [0.32191781],
#        [0.60958904],
#        [0.08675799],
#        [0.46118721],
#        [0.33105023],
#        [0.31278539],
#        [0.33333333],
#        [0.12557078],
#        [0.21004566],
#        [0.34474886],
#        [0.44748858],
#        [0.2739726 ],
#        [0.33333333],
#        [0.98858447],
#        [0.38127854],
#        [0.35159817],
#        [0.24200913],
#        [0.38812785],
#        [0.88584475],
#        [0.1347032 ],
#        [0.9086758 ],
#        [0.12557078],
#        [0.26027397],
#        [0.18493151],
#        [0.43150685],
#        [0.42922374],
#        [0.56164384],
#        [0.42237443],
#        [0.2260274 ],
#        [0.50456621],
#        [0.32648402],
#        [0.6826484 ],
#        [0.30821918],
#        [0.36986301],
#        [0.32876712],
#        [0.38584475],
#        [0.35616438],
#        [0.62557078],
#        [0.4109589 ],
#        [0.63242009],
#        [0.8630137 ],
#        [0.37671233],
#        [0.38127854],
#        [0.42922374],
#        [0.31278539],
#        [0.36757991],
#        [0.4086758 ],
#        [0.41780822],
#        [0.17579909],
#        [0.35844749],
#        [0.39269406],
#        [0.38812785],
#        [0.44520548],
#        [0.4109589 ],
#        [0.26712329],
#        [0.02968037],
#        [0.37899543],
#        [0.82876712],
#        [0.25114155],
#        [0.2283105 ],
#        [0.43150685],
#        [0.20776256],
#        [0.44748858],
#        [0.1826484 ],
#        [0.43378995],
#        [0.42465753],
#        [0.33561644],
#        [0.17123288],
#        [0.19406393],
#        [0.36986301],
#        [0.56621005],
#        [0.41324201],
#        [0.51369863],
#        [0.30136986],
#        [0.45890411],
#        [0.29223744],
#        [0.24200913],
#        [0.44292237],
#        [0.08675799],
#        [0.15981735],
#        [0.28310502],
#        [0.39041096],
#        [0.30821918],
#        [0.60730594],
#        [0.44063927],
#        [0.38356164],
#        [0.52968037],
#        [0.26484018],
#        [0.64383562],
#        [0.35616438],
#        [0.        ],
#        [0.40639269],
#        [0.456621  ],
#        [0.64383562],
#        [0.44063927],
#        [0.70776256],
#        [0.13242009],
#        [0.6369863 ],
#        [0.48401826],
#        [0.99315068],
#        [0.40639269],
#        [0.25570776],
#        [0.05022831],
#        [0.43835616],
#        [0.59589041],
#        [0.40410959],
#        [0.28538813],
#        [0.41552511],
#        [0.73515982],
#        [0.52511416],
#        [0.30593607],
#        [0.15525114],
#        [0.43150685],
#        [0.52283105],
#        [0.24429224],
#        [0.64611872],
#        [0.44977169],
#        [0.3652968 ],
#        [0.32876712],
#        [0.31050228],
#        [0.38127854],
#        [0.76940639],
#        [0.32420091],
#        [0.21917808],
#        [0.43150685],
#        [0.18493151],
#        [0.49086758],
#        [0.2260274 ],
#        [0.15296804],
#        [0.29223744],
#        [0.79452055],
#        [0.34246575],
#        [0.71004566],
#        [0.21917808],
#        [0.39726027],
#        [0.41552511],
#        [0.42922374],
#        [0.31278539],
#        [0.20091324],
#        [0.26712329]])

# %%
m.evaluate(X_test, y_test)
# Out:
# 162/162 [==============================] - 0s 64us/step
# [0.054885676981490335, 0.05488567426800728, 0.006172839552164078]

# %%
# fit the model to the training data
y_pred = m.predict(X_test)

# %% [markdown]
# Let’s plot the predicted value against the actual value. The black broken line is the predicted values

# %% [markdown]
# ### To further visualize the predicted results, we can draw a regression plot.

# %%
y_test = scaler.inverse_transform(y_test)
y_pred = scaler.inverse_transform(y_pred)

# %%
import matplotlib.pyplot as plt

sns.set(style="whitegrid", palette="husl", rc={'figure.figsize':(11.7,8.27)})

#fig, ax = plt.subplots()
plt.scatter(y_test, y_pred)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
plt.xlabel('Measured')
plt.ylabel('Predicted')
plt.legend(['Predicted', 'Measured'], loc='upper right')

title="Predicted vs Measured"

# increasing font size
plt.title(title, fontsize=16)

plt.show()

# %%
predictions = m.predict(X_test)
predictions_labels = scaler.inverse_transform(predictions)
#predictions_labels = scaler.inverse_transform(predictions)
predictions_labels
# Out:
# array([[15035.093],
#        [34188.63 ],
#        [20940.002],
#        [19543.957],
#        [19697.725],
#        [24419.748],
#        [21845.91 ],
#        [24262.195],
#        [30901.543],
#        [14654.349],
#        [26389.38 ],
#        [25482.26 ],
#        [22190.38 ],
#        [10957.106],
#        [15973.766],
#        [22701.127],
#        [24376.066],
#        [19294.777],
#        [14882.703],
#        [34051.863],
#        [20716.97 ],
#        [12818.607],
#        [21576.316],
#        [37103.793],
#        [13166.217],
#        [25501.97 ],
#        [20643.562],
#        [20932.68 ],
#        [21651.303],
#        [ 9619.234],
#        [17857.25 ],
#        [21776.068],
#        [25833.13 ],
#        [19785.354],
#        [20243.223],
#        [43868.04 ],
#        [20684.385],
#        [19157.375],
#        [17698.27 ],
#        [24267.992],
#        [41826.2  ],
#        [13416.573],
#        [43942.004],
#        [12058.023],
#        [17112.105],
#        [11358.049],
#        [29326.318],
#        [21492.654],
#        [21474.16 ],
#        [27097.23 ],
#        [15522.565],
#        [20207.885],
#        [20472.154],
#        [36697.543],
#        [23369.266],
#        [21760.424],
#        [21420.691],
#        [20276.576],
#        [22188.016],
#        [32784.176],
#        [22591.568],
#        [36103.76 ],
#        [42345.46 ],
#        [19145.148],
#        [19207.783],
#        [24208.4  ],
#        [19881.81 ],
#        [20658.883],
#        [21368.094],
#        [27917.168],
#        [14348.593],
#        [23348.025],
#        [20762.852],
#        [24619.316],
#        [23872.418],
#        [24397.418],
#        [18884.602],
#        [ 8659.604],
#        [25121.012],
#        [28789.68 ],
#        [20010.152],
#        [20408.55 ],
#        [28310.68 ],
#        [15172.95 ],
#        [25112.932],
#        [14557.189],
#        [21666.771],
#        [34278.164],
#        [20863.21 ],
#        [14507.663],
#        [16042.477],
#        [21321.25 ],
#        [29894.678],
#        [28732.973],
#        [22078.023],
#        [19737.047],
#        [26075.242],
#        [14982.645],
#        [18216.656],
#        [27325.676],
#        [ 9364.638],
#        [10489.121],
#        [20089.236],
#        [24556.   ],
#        [20528.684],
#        [34476.504],
#        [21222.885],
#        [20632.936],
#        [30375.633],
#        [17859.193],
#        [35146.168],
#        [21402.816],
#        [11445.111],
#        [27410.258],
#        [23047.195],
#        [37147.117],
#        [22412.426],
#        [37142.156],
#        [11019.789],
#        [36004.254],
#        [28823.17 ],
#        [46731.535],
#        [24519.174],
#        [20857.953],
#        [ 9094.112],
#        [24528.04 ],
#        [31822.857],
#        [21846.334],
#        [21499.26 ],
#        [24245.861],
#        [34446.47 ],
#        [30415.875],
#        [16656.502],
#        [11269.435],
#        [25333.367],
#        [29502.217],
#        [ 9042.778],
#        [40242.676],
#        [26187.826],
#        [21553.58 ],
#        [21242.422],
#        [22000.008],
#        [20556.46 ],
#        [43261.684],
#        [21359.719],
#        [15240.341],
#        [23598.709],
#        [16170.841],
#        [23060.357],
#        [17168.094],
#        [18642.162],
#        [17935.758],
#        [39089.086],
#        [21592.164],
#        [34654.38 ],
#        [14407.177],
#        [22206.879],
#        [14609.482],
#        [25459.088],
#        [19968.912],
#        [ 8867.105],
#        [15033.246]], dtype=float32)

# %% [markdown]
# ### Evaluate

# %%
predictions_labels == scaler.inverse_transform(y_test)
# Out:
# array([[False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False]])

# %%
# how many are correct
(predictions_labels == scaler.inverse_transform(y_test)).sum()
# Out:
# 0

# %% [markdown]
# ### Ref:
# https://medium.com/@haydar_ai/learning-data-science-day-9-linear-regression-on-boston-housing-dataset-cd62a80775ef
# https://subscription.packtpub.com/book/big_data_and_business_intelligence/9781789804744/1/ch01lvl1sec11/our-first-analysis-the-boston-housing-dataset
#
# https://towardsdatascience.com/machine-learning-project-predicting-boston-house-prices-with-regression-b4e47493633d
#
# ### inferential statistics
# https://www.datavedas.com/inferential-statistics-in-python/
# https://en.wikipedia.org/wiki/P-value
#
# ## Correlation
# https://machinelearningmastery.com/how-to-use-correlation-to-understand-the-relationship-between-variables/
#
# https://rpubs.com/joelrudinas03/BostonHousingPrices

# %% [markdown]
# https://realpython.com/linear-regression-in-python/
#
# # Neural Network
# https://medium.com/datadriveninvestor/building-neural-network-using-keras-for-regression-ceee5a9eadff
#
#
# https://towardsdatascience.com/how-do-we-train-neural-networks-edd985562b73
#
# https://towardsdatascience.com/building-a-deep-learning-model-using-keras-1548ca149d37
#
# https://tensorflow.rstudio.com/keras/articles/tutorial_basic_regression.html
# https://cran.r-project.org/web/packages/keras/vignettes/getting_started.html
#
# https://olegleyz.github.io/boston_housing.html
