# %% [markdown]
# #### Boston House Prices dataset
#
# The boston dataset was first published in 1978 in a paper [Hedonic Housing Prices and the Demand for Clean Air ](http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.926.5532&rep=rep1&type=pdf) by Harrison and Rubenfield.  506 entries represent aggregated data about 14 features for homes in Boston and capture the Crime rate (CRIM), number of Rooms(RM), age(AGE) of owners and more. This dataset is widely used in many machine learning papers that address regression problems.
#
# #### Aims of this notebook:
#
# 1. Use **descriptive statistics** and plots to describe the Boston House Prices dataset.
# 2. Use **inferential statistics** to analyse whether there is a significant difference in median house prices between houses that are along the Charles river and those that aren’t. You should explain and discuss your findings within the notebook.
# 3. Use **keras** to create a neural network that can predict the median house price based on the other variables in the dataset.

# %% [markdown]
# ### Libraries used in this project

# %%
import numpy as np
import pandas as pd
# plots
import seaborn as sns
import matplotlib.pyplot as plt
# for creating folder for plots
import os
from random import random
# statistical analysis
import researchpy as rp
import statsmodels.api as sm
#for interactive widgets for charts
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets
# machine learning
import keras as kr
from keras.models import Sequential
from keras.layers import Dense
#from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
# Out:
# Using TensorFlow backend.

# %%
# importing the boston housing dataset
from sklearn.datasets import load_boston
boston_df = load_boston()

# %% [markdown]
# ## Exploring the data

# %%
# print the keys in the dataset
print(boston_df.keys())
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %% [markdown]
# To learn more about this dataset you can print the description

# %%
# DESC should tell us what the data is about
print(boston_df.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of UCI ML housing dataset.
# https://archive.ics.uci.edu/ml/machine-learning-databases/housing/
#
#
# This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression
# problems.
#
# .. topic:: References
#
#    - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#    - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.

# %%
# the feature name contain the columns of the dataset
print(boston_df.feature_names)
# Out:
# ['CRIM' 'ZN' 'INDUS' 'CHAS' 'NOX' 'RM' 'AGE' 'DIS' 'RAD' 'TAX' 'PTRATIO'
#  'B' 'LSTAT']

# %% [markdown]
# From inspecting the boston_df.filename, we can see that feature_names should be the columns and boston_df.data should be the rows

# %%
# create a new dataset called Boston using the feature_names as the columns
boston = pd.DataFrame(boston_df.data, columns=boston_df.feature_names)
# We are missing one column (MEDV). According to DESCR, Median Value (attribute 14) is usually the target.
boston['MEDV'] = boston_df.target

# Median value of owner-occupied homes in $1000's 
boston['MEDV'] = (boston['MEDV']*1000)

# glance at the data
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT     MEDV
# 0     15.3  396.90   4.98  24000.0
# 1     17.8  396.90   9.14  21600.0
# 2     17.8  392.83   4.03  34700.0
# 3     18.7  394.63   2.94  33400.0
# 4     18.7  396.90   5.33  36200.0

# %% [markdown]
# #### Date cleaning
# This is important for the machine learning part of the project
# - Check for null values, df.isnull().sum(). Luckily there is no null values in the dataset
# - Check for duplicates

# %% [markdown]
# There are 16 duplicates for MEDV of 50000.0. We need to remove them as they will throw off the predictions later in the project.

# %%
boston = (boston[boston.MEDV != 50000.0])

# %% [markdown]
# ## Part 1. Descriptive Statistics
# Use **descriptive statistics** and plots to describe the Boston House Prices dataset.
#
# Here we can quickly see the mean, standard deviation, min, max and various percentiles for the dataset.

# %%
# describe() gives us a quick overview of the dataset
summary = boston.describe()
summary = summary.transpose()
summary.round(2)
# Out:
#          count      mean      std      min       25%       50%       75%  \
# CRIM     490.0      3.64     8.72     0.01      0.08      0.25      3.65
# ZN       490.0     11.11    22.84     0.00      0.00      0.00     12.50
# INDUS    490.0     11.11     6.82     0.74      5.19      9.69     18.10
# CHAS     490.0      0.06     0.24     0.00      0.00      0.00      0.00
# NOX      490.0      0.55     0.12     0.38      0.45      0.54      0.62
# RM       490.0      6.25     0.65     3.56      5.88      6.18      6.58
# AGE      490.0     68.28    28.16     2.90     44.55     76.80     93.88
# DIS      490.0      3.83     2.11     1.14      2.11      3.28      5.21
# RAD      490.0      9.51     8.69     1.00      4.00      5.00     24.00
# TAX      490.0    408.00   168.07   187.00    280.25    330.00    666.00
# PTRATIO  490.0     18.52     2.11    12.60     17.40     19.10     20.20
# B        490.0    355.86    92.63     0.32    375.91    391.77    396.32
# LSTAT    490.0     12.92     7.08     1.98      7.35     11.68     17.12
# MEDV     490.0  21635.92  7865.30  5000.00  16700.00  20900.00  24675.00
#
#               max
# CRIM        88.98
# ZN         100.00
# INDUS       27.74
# CHAS         1.00
# NOX          0.87
# RM           8.78
# AGE        100.00
# DIS         12.13
# RAD         24.00
# TAX        711.00
# PTRATIO     22.00
# B          396.90
# LSTAT       37.97
# MEDV     48800.00

# %%
prices = boston['MEDV']
# TODO: Minimum price of the data
minimum_price = np.min(prices)

# TODO: Maximum price of the data
maximum_price = np.max(prices)

# TODO: Mean price of the data
mean_price = np.mean(prices)

# TODO: Median price of the data
median_price = np.median(prices)

# TODO: Standard deviation of prices of the data
std_price = np.std(prices)

# Show the calculated statistics
print ("Statistics for Boston housing dataset:")
print ("Minimum price: ${:,.2f}".format(minimum_price))
print ("Maximum price: ${:,.2f}".format(maximum_price))
print ("Mean price: ${:,.2f}".format(mean_price))
print( "Median price ${:,.2f}".format(median_price))
print ("Standard deviation of prices: ${:,.2f}".format(std_price))
# Out:
# Statistics for Boston housing dataset:
# Minimum price: $5,000.00
# Maximum price: $48,800.00
# Mean price: $21,635.92
# Median price $20,900.00
# Standard deviation of prices: $7,857.27

# %%
if not os.path.exists("plots/box"):
    os.makedirs("plots/box")

# random color for each plot     
import random
df_color = sns.color_palette("husl")
random.choice(df_color)

   
@interact

def box_plt(feature = list(boston.columns)):
    for i, value in enumerate(boston):
        sns.boxplot(boston[feature], orient="v", color=random.choice(df_color))
        plt.savefig("plots/box/box_" + str(i) + ".png")
# Out:
# interactive(children=(Dropdown(description='feature', options=('CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AG…

# %% [markdown]
# While researching this topic, I read this blog post:[Analysis of the Boston Housing Prices Dataset](https://rpubs.com/joelrudinas03/BostonHousingPrices) by Joel Jr Ffc Rudinas in R which uses a mixed correlation matrix to quickly investigate relationships between the variables. After looking for ways to do this in Python, I settled on the correlation heatmap using Seaborn:
#
# - **Positive Correlation**: both variables change in the same direction (light color).
#
# - **Neutral Correlation**: No relationship in the change of the variables.
#
# - **Negative Correlation**: variables change in opposite directions (dark color).

# %%
# using a correlation heatmap, we can quickly get a sense for any relationships between the dataset. The darkest and lightest squares show variables which have a strong relationship. 
plt.figure(figsize=(15, 10))
cmap=sns.cubehelix_palette(50, light=0.95, dark=0.15)

# rounding to 2 decimal places and increasing the font size
sns.heatmap(data=boston.corr().round(2), annot=True, annot_kws={"size":14})
#plt.tight_layout()

#save the plot
plt.savefig('plots/bostondatasetcorrelation.png')

# show plot
plt.show()

# %% [markdown]
# From the correlation heatmap
#
# - We can see a positive correlation between MEDV and RM at 0.69. When the average number of rooms increase the price of the house also increases.
# - Negative correlation between MEDV and LSTAT (% lower status of the population): -0.76
# - Negative correlation between MEDV and PTRatio (pupil-teacher ratio by town): (-0.52)
# - Negative correlation between MEDV and INDUS (proportion of non-retail business acres per town) (-0.6)
#
# Let's plot these to see more details:

# %%
sns.set(style="whitegrid",  rc={'figure.figsize':(11.7,8.27)})

df= boston[['RM','LSTAT','CRIM','INDUS','PTRATIO', 'MEDV']]

#create a folder to add the plots to
if not os.path.exists("plots/linearregression/"):
    os.makedirs("plots/linearregression/")

# random color from palette for each plot    
import random
df_color = sns.color_palette("husl")
random.choice(df_color)    
    
@interact
def scatter_plot(feature=list(df.select_dtypes('number').columns)):
    
    for i, col in enumerate(df):
       sns.regplot(x=feature, y='MEDV', data=df, color=random.choice(df_color))
       plt.savefig("plots/linearregression/linearreg_" + str(i) + ".png")
# Out:
# interactive(children=(Dropdown(description='feature', options=('RM', 'LSTAT', 'CRIM', 'INDUS', 'PTRATIO', 'MED…

# %%
sns.set(style="whitegrid", palette="BuGn_r", rc={'figure.figsize':(11.7,8.27)})

#sns.scatterplot(x='RM', y='MEDV', data=boston)
sns.regplot(x='RM', y='MEDV', data=boston)
title="Plotting the relationship between MEDV and RM"

# Set x-axis label
plt.xlabel('Average number of rooms')
# Set y-axis label
plt.ylabel('Median value (in 1000s)')

# increasing font size
plt.title(title, fontsize=16)

#save the plot
plt.savefig('plots/medvvrmrelationship.png')

# Show the plot
plt.show()

# %% [markdown]
# From the correlation heatmap, we can we a negative correlation between MEDV and LSTAT at -0.74. When the % of lower status of the populations increases the value of houses decrease.

# %%
sns.set(style="whitegrid", palette="BuGn_r", rc={'figure.figsize':(11.7,8.27)})


sns.regplot(x='LSTAT', y='MEDV', data=boston)
title="Plotting the relationship between MEDV and LSTAT"

# increasing font size
plt.title(title, fontsize=16)

# Set x-axis label
plt.xlabel('% lower status of the population')
# Set y-axis label
plt.ylabel('Median value of owner-occupied homes')

#save the plot
plt.savefig('plots/medvandlstatrelationship.png')

# Show the plot
plt.show()

# %% [markdown]
# # Part 2. Inferential Statistics

# %% [markdown]
# Use inferential statistics to analyse whether there is a significant difference in median house prices between houses that are along the Charles river and those that aren’t.

# %%
# Gettin summary statistics of MEDV for the population
rp.summary_cont(boston['MEDV'])
# Out:
#   Variable      N          Mean           SD          SE     95% Conf.  \
# 0     MEDV  490.0  21635.918367  7865.301063  355.318083  20937.779775
#
#       Interval
# 0  22334.05696

# %%
# let's look at the data grouped by whether they bound the River or otherwise.
rp.summary_cont(boston['MEDV'].groupby(boston['CHAS']))
# Out:
#         N          Mean           SD           SE     95% Conf.      Interval
# CHAS
# 0.0   461  21488.503254  7898.848164   367.886036  20766.663292  22210.343215
# 1.0    29  23979.310345  7024.161328  1304.354013  21377.524579  26581.096111

# %% [markdown]
# From the above summary we can see that the houses bound the river have a higher mean MEDV. Let's visualise this with a boxplot.

# %%
sns.set(style="whitegrid", palette="husl", rc={'figure.figsize':(11.7,8.27)})

sns.catplot(x='CHAS', y='MEDV', kind="box", data=boston)

title="Boxplot of the house prices"

# increasing font size
plt.title(title, fontsize=16)

#save the plot
plt.savefig('plots/boxplot.png')

plt.show()

# %%
riverhouse_df = boston[boston['CHAS']==1.0]
other_df = boston[boston['CHAS']==0.0]

# %%
import matplotlib.pyplot as plt
3
title="House prices"

# increasing font size
plt.title(title, fontsize=16)

plt.hist(other_df['MEDV'], label='Not River Bound')
plt.hist(riverhouse_df['MEDV'], label='Charles River houses')

# Set x-axis label
plt.xlabel('MEDV (Price)')
# Set y-axis label
plt.ylabel('Frequency')


plt.legend()

plt.savefig('plots/hist.png')

plt.show()

# %%
#add info about the One way Anova

# %%
#oneway anova
import scipy.stats as stats
stats.f_oneway(other_df['MEDV'], riverhouse_df['MEDV'])
# Out:
# F_onewayResult(statistic=2.7459981221672622, pvalue=0.098140893200901)

# %% [markdown]
# Check which dataset has the highest mean the population or the sample?

# %%
Mean1 = other_df.MEDV.mean()
Mean2 = riverhouse_df.MEDV.mean()
print("Mean price Boston house dataset (population):", Mean1)
print("mean price Charles river House (sample):", Mean2)
# Out:
# Mean price Boston house dataset (population): 21488.503253796094
# mean price Charles river House (sample): 23979.310344827587

# %% [markdown]
# ### Z-test

# %% [markdown]
# Comparing the mean of the house not by the river (22.09) and river bound (28.44) looks much bigger however we can use a Z-TEST to check if it is statistically significant. We use use a z-test when the sample is greater than 30 and riverhouse_df has 35.

# %%
# Convert into two arrays
X2 = np.array(other_df.MEDV)
Y2 = np.array(riverhouse_df.MEDV)

# %%
# import the package for performing Z Test
from statsmodels.stats.weightstats import ztest

# %%
ztest(Y2,x2=None,value=Mean1)
# Out:
# (1.9096097115736, 0.056183483767629605)

# %% [markdown]
# p value is 0.0014868133390002274 which is lower than 0.05 and therefore is statistically significant.

# %% [markdown]
# # 3. Predict
#
# Use keras to create a neural network that can predict the median house price based on the other variables in the dataset.
#
# The target variable, 'MEDV', will be the variable we seek to predict.
#
# https://towardsdatascience.com/how-do-we-train-neural-networks-edd985562b73
#
# https://towardsdatascience.com/building-a-deep-learning-model-using-keras-1548ca149d37
#
# https://tensorflow.rstudio.com/keras/articles/tutorial_basic_regression.html
# https://cran.r-project.org/web/packages/keras/vignettes/getting_started.html

# %%
# first neural network with keras tutorial
#importing libraries
import numpy as np
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# The first thing to get right is to ensure the input layer has the right number of input features. I will only take what I consider the interesting features which had a strong correlation with MEDV.

# %%
#input features (X) 
#inputs = boston.iloc[:, 0:13]
# only take the features that have a strong correlation of MEDV
features = boston[['RM', 'LSTAT', 'PTRATIO', 'INDUS']]
#train_X = boston.drop(columns=['MEDV'])
# What we want to predict
#train_y = boston.iloc[:,13]
prices = boston[['MEDV']]

# %% [markdown]
# ### Normalising the data
# A best practices I came across when researching Neural Networks was to normalise the data to see better results.

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
#features= pd.DataFrame(scaler.fit_transform(features), columns=features.columns)
features= scaler.fit_transform(features)
prices= prices.values.reshape(-1,1)
#prices = pd.DataFrame(scaler.fit_transform(prices), columns=prices.columns)
prices = scaler.fit_transform(prices)

# %% [markdown]
# ### Create train and test split

# %%
from sklearn.model_selection import train_test_split

# Shuffle and split the data into training and testing subsets
X_train, X_test, y_train, y_test = train_test_split(features, prices, test_size=0.33, random_state=10)

# Success
print("Training and testing split was successful.")
# Out:
# Training and testing split was successful.

# %%
# checking, it should be divided in to 80% train, 20% test
print(features.shape[0])
print("Train:", float(X_train.shape[0]) / float(features.shape[0]))
print("Test:", float(X_test.shape[0]) / float(features.shape[0]))
# Out:
# 490
# Train: 0.6693877551020408
# Test: 0.3306122448979592

# %% [markdown]
# As this a regression problem, the loss function we use is mean squared error and the metrics against which we evaluate the performance of the model is mean absolute error and accuracy. Also the output layer should be linear also.

# %%
from keras.callbacks import ModelCheckpoint
m = kr.models.Sequential()

n_cols = X_train.shape[1]
# The Input Layer :
m.add(kr.layers.Dense(128, kernel_initializer='normal',input_shape=(n_cols,), activation='relu'))
# The Hidden Layers :
m.add(kr.layers.Dense(256, kernel_initializer='normal',activation='relu'))

m.add(kr.layers.Dense(128, kernel_initializer='normal',activation='relu'))

# The Output Layer :
m.add(kr.layers.Dense(1, kernel_initializer='normal',activation='linear'))


# Compile the network :
m.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error', 'accuracy'])
print(m.summary())

# checkpoint
filepath="weights.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

hist = m.fit(X_train, y_train, epochs=100, batch_size=6, validation_data=(X_test,y_test), callbacks=callbacks_list)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               640
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 66,689
# Trainable params: 66,689
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 328 samples, validate on 162 samples
# Epoch 1/100
# 328/328 [==============================] - 1s 4ms/step - loss: 0.1502 - mean_absolute_error: 0.1502 - accuracy: 0.0061 - val_loss: 0.0960 - val_mean_absolute_error: 0.0960 - val_accuracy: 0.0062
#
# Epoch 00001: val_accuracy improved from -inf to 0.00617, saving model to weights.best.hdf5
# Epoch 2/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0753 - mean_absolute_error: 0.0753 - accuracy: 0.0061 - val_loss: 0.0657 - val_mean_absolute_error: 0.0657 - val_accuracy: 0.0062
#
# Epoch 00002: val_accuracy did not improve from 0.00617
# Epoch 3/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0707 - mean_absolute_error: 0.0707 - accuracy: 0.0061 - val_loss: 0.0684 - val_mean_absolute_error: 0.0684 - val_accuracy: 0.0062
#
# Epoch 00003: val_accuracy did not improve from 0.00617
# Epoch 4/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0711 - mean_absolute_error: 0.0711 - accuracy: 0.0061 - val_loss: 0.0576 - val_mean_absolute_error: 0.0576 - val_accuracy: 0.0062
#
# Epoch 00004: val_accuracy did not improve from 0.00617
# Epoch 5/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0747 - mean_absolute_error: 0.0747 - accuracy: 0.0061 - val_loss: 0.0606 - val_mean_absolute_error: 0.0606 - val_accuracy: 0.0062
#
# Epoch 00005: val_accuracy did not improve from 0.00617
# Epoch 6/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0696 - mean_absolute_error: 0.0696 - accuracy: 0.0061 - val_loss: 0.0646 - val_mean_absolute_error: 0.0646 - val_accuracy: 0.0062
#
# Epoch 00006: val_accuracy did not improve from 0.00617
# Epoch 7/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0700 - mean_absolute_error: 0.0700 - accuracy: 0.0061 - val_loss: 0.0623 - val_mean_absolute_error: 0.0623 - val_accuracy: 0.0062
#
# Epoch 00007: val_accuracy did not improve from 0.00617
# Epoch 8/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0674 - mean_absolute_error: 0.0674 - accuracy: 0.0061 - val_loss: 0.0571 - val_mean_absolute_error: 0.0571 - val_accuracy: 0.0062
#
# Epoch 00008: val_accuracy did not improve from 0.00617
# Epoch 9/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0656 - mean_absolute_error: 0.0656 - accuracy: 0.0061 - val_loss: 0.0630 - val_mean_absolute_error: 0.0630 - val_accuracy: 0.0062
#
# Epoch 00009: val_accuracy did not improve from 0.00617
# Epoch 10/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0656 - mean_absolute_error: 0.0656 - accuracy: 0.0061 - val_loss: 0.0585 - val_mean_absolute_error: 0.0585 - val_accuracy: 0.0062
#
# Epoch 00010: val_accuracy did not improve from 0.00617
# Epoch 11/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0623 - mean_absolute_error: 0.0623 - accuracy: 0.0061 - val_loss: 0.0817 - val_mean_absolute_error: 0.0817 - val_accuracy: 0.0062
#
# Epoch 00011: val_accuracy did not improve from 0.00617
# Epoch 12/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0650 - mean_absolute_error: 0.0650 - accuracy: 0.0061 - val_loss: 0.0605 - val_mean_absolute_error: 0.0605 - val_accuracy: 0.0062
#
# Epoch 00012: val_accuracy did not improve from 0.00617
# Epoch 13/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0650 - mean_absolute_error: 0.0650 - accuracy: 0.0061 - val_loss: 0.0564 - val_mean_absolute_error: 0.0564 - val_accuracy: 0.0062
#
# Epoch 00013: val_accuracy did not improve from 0.00617
# Epoch 14/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0719 - mean_absolute_error: 0.0719 - accuracy: 0.0061 - val_loss: 0.0579 - val_mean_absolute_error: 0.0579 - val_accuracy: 0.0062
#
# Epoch 00014: val_accuracy did not improve from 0.00617
# Epoch 15/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0650 - mean_absolute_error: 0.0650 - accuracy: 0.0061 - val_loss: 0.0710 - val_mean_absolute_error: 0.0710 - val_accuracy: 0.0062
#
# Epoch 00015: val_accuracy did not improve from 0.00617
# Epoch 16/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0627 - mean_absolute_error: 0.0627 - accuracy: 0.0061 - val_loss: 0.0539 - val_mean_absolute_error: 0.0539 - val_accuracy: 0.0062
#
# Epoch 00016: val_accuracy did not improve from 0.00617
# Epoch 17/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0635 - mean_absolute_error: 0.0635 - accuracy: 0.0061 - val_loss: 0.0585 - val_mean_absolute_error: 0.0585 - val_accuracy: 0.0062
#
# Epoch 00017: val_accuracy did not improve from 0.00617
# Epoch 18/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0610 - mean_absolute_error: 0.0610 - accuracy: 0.0061 - val_loss: 0.0621 - val_mean_absolute_error: 0.0621 - val_accuracy: 0.0062
#
# Epoch 00018: val_accuracy did not improve from 0.00617
# Epoch 19/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0605 - mean_absolute_error: 0.0605 - accuracy: 0.0061 - val_loss: 0.0612 - val_mean_absolute_error: 0.0612 - val_accuracy: 0.0062
#
# Epoch 00019: val_accuracy did not improve from 0.00617
# Epoch 20/100
# 328/328 [==============================] - 0s 991us/step - loss: 0.0633 - mean_absolute_error: 0.0633 - accuracy: 0.0061 - val_loss: 0.0579 - val_mean_absolute_error: 0.0579 - val_accuracy: 0.0062
#
# Epoch 00020: val_accuracy did not improve from 0.00617
# Epoch 21/100
# 328/328 [==============================] - 0s 994us/step - loss: 0.0625 - mean_absolute_error: 0.0625 - accuracy: 0.0061 - val_loss: 0.0529 - val_mean_absolute_error: 0.0529 - val_accuracy: 0.0062
#
# Epoch 00021: val_accuracy did not improve from 0.00617
# Epoch 22/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0651 - mean_absolute_error: 0.0651 - accuracy: 0.0061 - val_loss: 0.0547 - val_mean_absolute_error: 0.0547 - val_accuracy: 0.0062
#
# Epoch 00022: val_accuracy did not improve from 0.00617
# Epoch 23/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0616 - mean_absolute_error: 0.0616 - accuracy: 0.0061 - val_loss: 0.0592 - val_mean_absolute_error: 0.0592 - val_accuracy: 0.0062
#
# Epoch 00023: val_accuracy did not improve from 0.00617
# Epoch 24/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0640 - mean_absolute_error: 0.0640 - accuracy: 0.0061 - val_loss: 0.0545 - val_mean_absolute_error: 0.0545 - val_accuracy: 0.0062
#
# Epoch 00024: val_accuracy did not improve from 0.00617
# Epoch 25/100
# 328/328 [==============================] - 0s 993us/step - loss: 0.0634 - mean_absolute_error: 0.0634 - accuracy: 0.0061 - val_loss: 0.0530 - val_mean_absolute_error: 0.0530 - val_accuracy: 0.0062
#
# Epoch 00025: val_accuracy did not improve from 0.00617
# Epoch 26/100
# 328/328 [==============================] - 0s 987us/step - loss: 0.0615 - mean_absolute_error: 0.0615 - accuracy: 0.0061 - val_loss: 0.0648 - val_mean_absolute_error: 0.0648 - val_accuracy: 0.0062
#
# Epoch 00026: val_accuracy did not improve from 0.00617
# Epoch 27/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0620 - mean_absolute_error: 0.0620 - accuracy: 0.0061 - val_loss: 0.0519 - val_mean_absolute_error: 0.0519 - val_accuracy: 0.0062
#
# Epoch 00027: val_accuracy did not improve from 0.00617
# Epoch 28/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0617 - mean_absolute_error: 0.0617 - accuracy: 0.0061 - val_loss: 0.0528 - val_mean_absolute_error: 0.0528 - val_accuracy: 0.0062
#
# Epoch 00028: val_accuracy did not improve from 0.00617
# Epoch 29/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0594 - mean_absolute_error: 0.0594 - accuracy: 0.0061 - val_loss: 0.0543 - val_mean_absolute_error: 0.0543 - val_accuracy: 0.0062
#
# Epoch 00029: val_accuracy did not improve from 0.00617
# Epoch 30/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0612 - mean_absolute_error: 0.0612 - accuracy: 0.0061 - val_loss: 0.0511 - val_mean_absolute_error: 0.0511 - val_accuracy: 0.0062
#
# Epoch 00030: val_accuracy did not improve from 0.00617
# Epoch 31/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0620 - mean_absolute_error: 0.0620 - accuracy: 0.0061 - val_loss: 0.0557 - val_mean_absolute_error: 0.0557 - val_accuracy: 0.0062
#
# Epoch 00031: val_accuracy did not improve from 0.00617
# Epoch 32/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0606 - mean_absolute_error: 0.0606 - accuracy: 0.0061 - val_loss: 0.0532 - val_mean_absolute_error: 0.0532 - val_accuracy: 0.0062
#
# Epoch 00032: val_accuracy did not improve from 0.00617
# Epoch 33/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0598 - mean_absolute_error: 0.0598 - accuracy: 0.0061 - val_loss: 0.0605 - val_mean_absolute_error: 0.0605 - val_accuracy: 0.0062
#
# Epoch 00033: val_accuracy did not improve from 0.00617
# Epoch 34/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0619 - mean_absolute_error: 0.0619 - accuracy: 0.0061 - val_loss: 0.0514 - val_mean_absolute_error: 0.0514 - val_accuracy: 0.0062
#
# Epoch 00034: val_accuracy did not improve from 0.00617
# Epoch 35/100
# 328/328 [==============================] - 0s 997us/step - loss: 0.0608 - mean_absolute_error: 0.0608 - accuracy: 0.0061 - val_loss: 0.0565 - val_mean_absolute_error: 0.0565 - val_accuracy: 0.0062
#
# Epoch 00035: val_accuracy did not improve from 0.00617
# Epoch 36/100
# 328/328 [==============================] - 0s 988us/step - loss: 0.0577 - mean_absolute_error: 0.0577 - accuracy: 0.0061 - val_loss: 0.0516 - val_mean_absolute_error: 0.0516 - val_accuracy: 0.0062
#
# Epoch 00036: val_accuracy did not improve from 0.00617
# Epoch 37/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0587 - mean_absolute_error: 0.0587 - accuracy: 0.0061 - val_loss: 0.0556 - val_mean_absolute_error: 0.0556 - val_accuracy: 0.0062
#
# Epoch 00037: val_accuracy did not improve from 0.00617
# Epoch 38/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0588 - mean_absolute_error: 0.0588 - accuracy: 0.0061 - val_loss: 0.0555 - val_mean_absolute_error: 0.0555 - val_accuracy: 0.0062
#
# Epoch 00038: val_accuracy did not improve from 0.00617
# Epoch 39/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0617 - mean_absolute_error: 0.0617 - accuracy: 0.0061 - val_loss: 0.0521 - val_mean_absolute_error: 0.0521 - val_accuracy: 0.0062
#
# Epoch 00039: val_accuracy did not improve from 0.00617
# Epoch 40/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0600 - mean_absolute_error: 0.0600 - accuracy: 0.0061 - val_loss: 0.0583 - val_mean_absolute_error: 0.0583 - val_accuracy: 0.0062
#
# Epoch 00040: val_accuracy did not improve from 0.00617
# Epoch 41/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0610 - mean_absolute_error: 0.0610 - accuracy: 0.0061 - val_loss: 0.0637 - val_mean_absolute_error: 0.0637 - val_accuracy: 0.0062
#
# Epoch 00041: val_accuracy did not improve from 0.00617
# Epoch 42/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0581 - mean_absolute_error: 0.0581 - accuracy: 0.0061 - val_loss: 0.0500 - val_mean_absolute_error: 0.0500 - val_accuracy: 0.0062
#
# Epoch 00042: val_accuracy did not improve from 0.00617
# Epoch 43/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0584 - mean_absolute_error: 0.0584 - accuracy: 0.0061 - val_loss: 0.0559 - val_mean_absolute_error: 0.0559 - val_accuracy: 0.0062
#
# Epoch 00043: val_accuracy did not improve from 0.00617
# Epoch 44/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0597 - mean_absolute_error: 0.0597 - accuracy: 0.0061 - val_loss: 0.0600 - val_mean_absolute_error: 0.0600 - val_accuracy: 0.0062
#
# Epoch 00044: val_accuracy did not improve from 0.00617
# Epoch 45/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0623 - mean_absolute_error: 0.0623 - accuracy: 0.0061 - val_loss: 0.0618 - val_mean_absolute_error: 0.0618 - val_accuracy: 0.0062
#
# Epoch 00045: val_accuracy did not improve from 0.00617
# Epoch 46/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0576 - mean_absolute_error: 0.0576 - accuracy: 0.0061 - val_loss: 0.0549 - val_mean_absolute_error: 0.0549 - val_accuracy: 0.0062
#
# Epoch 00046: val_accuracy did not improve from 0.00617
# Epoch 47/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0571 - mean_absolute_error: 0.0571 - accuracy: 0.0061 - val_loss: 0.0598 - val_mean_absolute_error: 0.0598 - val_accuracy: 0.0062
#
# Epoch 00047: val_accuracy did not improve from 0.00617
# Epoch 48/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0587 - mean_absolute_error: 0.0587 - accuracy: 0.0061 - val_loss: 0.0695 - val_mean_absolute_error: 0.0695 - val_accuracy: 0.0062
#
# Epoch 00048: val_accuracy did not improve from 0.00617
# Epoch 49/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0603 - mean_absolute_error: 0.0603 - accuracy: 0.0061 - val_loss: 0.0517 - val_mean_absolute_error: 0.0517 - val_accuracy: 0.0062
#
# Epoch 00049: val_accuracy did not improve from 0.00617
# Epoch 50/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0567 - mean_absolute_error: 0.0567 - accuracy: 0.0061 - val_loss: 0.0506 - val_mean_absolute_error: 0.0506 - val_accuracy: 0.0062
#
# Epoch 00050: val_accuracy did not improve from 0.00617
# Epoch 51/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0571 - mean_absolute_error: 0.0571 - accuracy: 0.0061 - val_loss: 0.0557 - val_mean_absolute_error: 0.0557 - val_accuracy: 0.0062
#
# Epoch 00051: val_accuracy did not improve from 0.00617
# Epoch 52/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0604 - mean_absolute_error: 0.0604 - accuracy: 0.0061 - val_loss: 0.0511 - val_mean_absolute_error: 0.0511 - val_accuracy: 0.0062
#
# Epoch 00052: val_accuracy did not improve from 0.00617
# Epoch 53/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0556 - mean_absolute_error: 0.0556 - accuracy: 0.0061 - val_loss: 0.0522 - val_mean_absolute_error: 0.0522 - val_accuracy: 0.0062
#
# Epoch 00053: val_accuracy did not improve from 0.00617
# Epoch 54/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0564 - mean_absolute_error: 0.0564 - accuracy: 0.0061 - val_loss: 0.0536 - val_mean_absolute_error: 0.0536 - val_accuracy: 0.0062
#
# Epoch 00054: val_accuracy did not improve from 0.00617
# Epoch 55/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0557 - mean_absolute_error: 0.0557 - accuracy: 0.0061 - val_loss: 0.0517 - val_mean_absolute_error: 0.0517 - val_accuracy: 0.0062
#
# Epoch 00055: val_accuracy did not improve from 0.00617
# Epoch 56/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0599 - mean_absolute_error: 0.0599 - accuracy: 0.0061 - val_loss: 0.0676 - val_mean_absolute_error: 0.0676 - val_accuracy: 0.0062
#
# Epoch 00056: val_accuracy did not improve from 0.00617
# Epoch 57/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0609 - mean_absolute_error: 0.0609 - accuracy: 0.0061 - val_loss: 0.0562 - val_mean_absolute_error: 0.0562 - val_accuracy: 0.0062
#
# Epoch 00057: val_accuracy did not improve from 0.00617
# Epoch 58/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0558 - mean_absolute_error: 0.0558 - accuracy: 0.0061 - val_loss: 0.0523 - val_mean_absolute_error: 0.0523 - val_accuracy: 0.0062
#
# Epoch 00058: val_accuracy did not improve from 0.00617
# Epoch 59/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0592 - mean_absolute_error: 0.0592 - accuracy: 0.0061 - val_loss: 0.0510 - val_mean_absolute_error: 0.0510 - val_accuracy: 0.0062
#
# Epoch 00059: val_accuracy did not improve from 0.00617
# Epoch 60/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0551 - mean_absolute_error: 0.0551 - accuracy: 0.0061 - val_loss: 0.0503 - val_mean_absolute_error: 0.0503 - val_accuracy: 0.0062
#
# Epoch 00060: val_accuracy did not improve from 0.00617
# Epoch 61/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0548 - mean_absolute_error: 0.0548 - accuracy: 0.0061 - val_loss: 0.0542 - val_mean_absolute_error: 0.0542 - val_accuracy: 0.0062
#
# Epoch 00061: val_accuracy did not improve from 0.00617
# Epoch 62/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0592 - mean_absolute_error: 0.0592 - accuracy: 0.0061 - val_loss: 0.0615 - val_mean_absolute_error: 0.0615 - val_accuracy: 0.0062
#
# Epoch 00062: val_accuracy did not improve from 0.00617
# Epoch 63/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0566 - mean_absolute_error: 0.0566 - accuracy: 0.0061 - val_loss: 0.0524 - val_mean_absolute_error: 0.0524 - val_accuracy: 0.0062
#
# Epoch 00063: val_accuracy did not improve from 0.00617
# Epoch 64/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0536 - mean_absolute_error: 0.0536 - accuracy: 0.0061 - val_loss: 0.0498 - val_mean_absolute_error: 0.0498 - val_accuracy: 0.0062
#
# Epoch 00064: val_accuracy did not improve from 0.00617
# Epoch 65/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0542 - mean_absolute_error: 0.0542 - accuracy: 0.0061 - val_loss: 0.0554 - val_mean_absolute_error: 0.0554 - val_accuracy: 0.0062
#
# Epoch 00065: val_accuracy did not improve from 0.00617
# Epoch 66/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0550 - mean_absolute_error: 0.0550 - accuracy: 0.0061 - val_loss: 0.0511 - val_mean_absolute_error: 0.0511 - val_accuracy: 0.0062
#
# Epoch 00066: val_accuracy did not improve from 0.00617
# Epoch 67/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0564 - mean_absolute_error: 0.0564 - accuracy: 0.0061 - val_loss: 0.0631 - val_mean_absolute_error: 0.0631 - val_accuracy: 0.0062
#
# Epoch 00067: val_accuracy did not improve from 0.00617
# Epoch 68/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0572 - mean_absolute_error: 0.0572 - accuracy: 0.0061 - val_loss: 0.0482 - val_mean_absolute_error: 0.0482 - val_accuracy: 0.0062
#
# Epoch 00068: val_accuracy did not improve from 0.00617
# Epoch 69/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0541 - mean_absolute_error: 0.0541 - accuracy: 0.0061 - val_loss: 0.0560 - val_mean_absolute_error: 0.0560 - val_accuracy: 0.0062
#
# Epoch 00069: val_accuracy did not improve from 0.00617
# Epoch 70/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0551 - mean_absolute_error: 0.0551 - accuracy: 0.0061 - val_loss: 0.0520 - val_mean_absolute_error: 0.0520 - val_accuracy: 0.0062
#
# Epoch 00070: val_accuracy did not improve from 0.00617
# Epoch 71/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0527 - mean_absolute_error: 0.0527 - accuracy: 0.0061 - val_loss: 0.0537 - val_mean_absolute_error: 0.0537 - val_accuracy: 0.0062
#
# Epoch 00071: val_accuracy did not improve from 0.00617
# Epoch 72/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0551 - mean_absolute_error: 0.0551 - accuracy: 0.0061 - val_loss: 0.0502 - val_mean_absolute_error: 0.0502 - val_accuracy: 0.0062
#
# Epoch 00072: val_accuracy did not improve from 0.00617
# Epoch 73/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0566 - mean_absolute_error: 0.0566 - accuracy: 0.0061 - val_loss: 0.0505 - val_mean_absolute_error: 0.0505 - val_accuracy: 0.0062
#
# Epoch 00073: val_accuracy did not improve from 0.00617
# Epoch 74/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0606 - mean_absolute_error: 0.0606 - accuracy: 0.0061 - val_loss: 0.0517 - val_mean_absolute_error: 0.0517 - val_accuracy: 0.0062
#
# Epoch 00074: val_accuracy did not improve from 0.00617
# Epoch 75/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0557 - mean_absolute_error: 0.0557 - accuracy: 0.0061 - val_loss: 0.0616 - val_mean_absolute_error: 0.0616 - val_accuracy: 0.0062
#
# Epoch 00075: val_accuracy did not improve from 0.00617
# Epoch 76/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0556 - mean_absolute_error: 0.0556 - accuracy: 0.0061 - val_loss: 0.0523 - val_mean_absolute_error: 0.0523 - val_accuracy: 0.0062
#
# Epoch 00076: val_accuracy did not improve from 0.00617
# Epoch 77/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0549 - mean_absolute_error: 0.0549 - accuracy: 0.0061 - val_loss: 0.0523 - val_mean_absolute_error: 0.0523 - val_accuracy: 0.0062
#
# Epoch 00077: val_accuracy did not improve from 0.00617
# Epoch 78/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0545 - mean_absolute_error: 0.0545 - accuracy: 0.0061 - val_loss: 0.0500 - val_mean_absolute_error: 0.0500 - val_accuracy: 0.0062
#
# Epoch 00078: val_accuracy did not improve from 0.00617
# Epoch 79/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0543 - mean_absolute_error: 0.0543 - accuracy: 0.0061 - val_loss: 0.0501 - val_mean_absolute_error: 0.0501 - val_accuracy: 0.0062
#
# Epoch 00079: val_accuracy did not improve from 0.00617
# Epoch 80/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0545 - mean_absolute_error: 0.0545 - accuracy: 0.0061 - val_loss: 0.0553 - val_mean_absolute_error: 0.0553 - val_accuracy: 0.0062
#
# Epoch 00080: val_accuracy did not improve from 0.00617
# Epoch 81/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0534 - mean_absolute_error: 0.0534 - accuracy: 0.0061 - val_loss: 0.0563 - val_mean_absolute_error: 0.0563 - val_accuracy: 0.0062
#
# Epoch 00081: val_accuracy did not improve from 0.00617
# Epoch 82/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0540 - mean_absolute_error: 0.0540 - accuracy: 0.0061 - val_loss: 0.0486 - val_mean_absolute_error: 0.0486 - val_accuracy: 0.0062
#
# Epoch 00082: val_accuracy did not improve from 0.00617
# Epoch 83/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0533 - mean_absolute_error: 0.0533 - accuracy: 0.0061 - val_loss: 0.0574 - val_mean_absolute_error: 0.0574 - val_accuracy: 0.0062
#
# Epoch 00083: val_accuracy did not improve from 0.00617
# Epoch 84/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0584 - mean_absolute_error: 0.0584 - accuracy: 0.0061 - val_loss: 0.0506 - val_mean_absolute_error: 0.0506 - val_accuracy: 0.0062
#
# Epoch 00084: val_accuracy did not improve from 0.00617
# Epoch 85/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0521 - mean_absolute_error: 0.0521 - accuracy: 0.0061 - val_loss: 0.0493 - val_mean_absolute_error: 0.0493 - val_accuracy: 0.0062
#
# Epoch 00085: val_accuracy did not improve from 0.00617
# Epoch 86/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0536 - mean_absolute_error: 0.0536 - accuracy: 0.0061 - val_loss: 0.0501 - val_mean_absolute_error: 0.0501 - val_accuracy: 0.0062
#
# Epoch 00086: val_accuracy did not improve from 0.00617
# Epoch 87/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0528 - mean_absolute_error: 0.0528 - accuracy: 0.0061 - val_loss: 0.0499 - val_mean_absolute_error: 0.0499 - val_accuracy: 0.0062
#
# Epoch 00087: val_accuracy did not improve from 0.00617
# Epoch 88/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0542 - mean_absolute_error: 0.0542 - accuracy: 0.0061 - val_loss: 0.0551 - val_mean_absolute_error: 0.0551 - val_accuracy: 0.0062
#
# Epoch 00088: val_accuracy did not improve from 0.00617
# Epoch 89/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0549 - mean_absolute_error: 0.0549 - accuracy: 0.0061 - val_loss: 0.0540 - val_mean_absolute_error: 0.0540 - val_accuracy: 0.0062
#
# Epoch 00089: val_accuracy did not improve from 0.00617
# Epoch 90/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0526 - mean_absolute_error: 0.0526 - accuracy: 0.0061 - val_loss: 0.0570 - val_mean_absolute_error: 0.0570 - val_accuracy: 0.0062
#
# Epoch 00090: val_accuracy did not improve from 0.00617
# Epoch 91/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0524 - mean_absolute_error: 0.0524 - accuracy: 0.0061 - val_loss: 0.0578 - val_mean_absolute_error: 0.0578 - val_accuracy: 0.0062
#
# Epoch 00091: val_accuracy did not improve from 0.00617
# Epoch 92/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0519 - mean_absolute_error: 0.0519 - accuracy: 0.0061 - val_loss: 0.0521 - val_mean_absolute_error: 0.0521 - val_accuracy: 0.0062
#
# Epoch 00092: val_accuracy did not improve from 0.00617
# Epoch 93/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0554 - mean_absolute_error: 0.0554 - accuracy: 0.0061 - val_loss: 0.0570 - val_mean_absolute_error: 0.0570 - val_accuracy: 0.0062
#
# Epoch 00093: val_accuracy did not improve from 0.00617
# Epoch 94/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0527 - mean_absolute_error: 0.0527 - accuracy: 0.0061 - val_loss: 0.0490 - val_mean_absolute_error: 0.0490 - val_accuracy: 0.0062
#
# Epoch 00094: val_accuracy did not improve from 0.00617
# Epoch 95/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0544 - mean_absolute_error: 0.0544 - accuracy: 0.0061 - val_loss: 0.0517 - val_mean_absolute_error: 0.0517 - val_accuracy: 0.0062
#
# Epoch 00095: val_accuracy did not improve from 0.00617
# Epoch 96/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0521 - mean_absolute_error: 0.0521 - accuracy: 0.0061 - val_loss: 0.0646 - val_mean_absolute_error: 0.0646 - val_accuracy: 0.0062
#
# Epoch 00096: val_accuracy did not improve from 0.00617
# Epoch 97/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0524 - mean_absolute_error: 0.0524 - accuracy: 0.0061 - val_loss: 0.0501 - val_mean_absolute_error: 0.0501 - val_accuracy: 0.0062
#
# Epoch 00097: val_accuracy did not improve from 0.00617
# Epoch 98/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0522 - mean_absolute_error: 0.0522 - accuracy: 0.0061 - val_loss: 0.0700 - val_mean_absolute_error: 0.0700 - val_accuracy: 0.0062
#
# Epoch 00098: val_accuracy did not improve from 0.00617
# Epoch 99/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0608 - mean_absolute_error: 0.0608 - accuracy: 0.0061 - val_loss: 0.0491 - val_mean_absolute_error: 0.0491 - val_accuracy: 0.0062
#
# Epoch 00099: val_accuracy did not improve from 0.00617
# Epoch 100/100
# 328/328 [==============================] - 0s 1ms/step - loss: 0.0513 - mean_absolute_error: 0.0513 - accuracy: 0.0061 - val_loss: 0.0508 - val_mean_absolute_error: 0.0508 - val_accuracy: 0.0062
#
# Epoch 00100: val_accuracy did not improve from 0.00617

# %%
results=m.fit(X_train,y_train)
# Out:
# Epoch 1/1
# 328/328 [==============================] - 0s 211us/step - loss: 0.0506 - mean_absolute_error: 0.0506 - accuracy: 0.0061

# %%
#print(m.metrics_names)
score = m.evaluate(X_test, y_test, verbose = 0)
print("Loss:", score[0])
print("mean_absolute_error:", score[1])
print("Test Accuracy:", score[2])
# epoch 500
# Test Score: 2214.4743403220664
# Test Accuracy: 2214.474609375

# after adding two extra hidden layers
# Test Score: 2549.8913624043366
# Test Accuracy: 2549.891357421875

# epoch 1000
# Test Score: 2241.6360710299746
# Test Accuracy: 2241.635986328125

# before normalise the data
#Test Score: 2326.835857780612
#Test Accuracy: 2326.8359375

# before increasing split from .2 to .33
#Test Score: 0.05484031901067617
#Test Accuracy: 0.0548403225839138

# before increasing split  to .33
# Test Score: 0.04884675402700165
# Test Accuracy: 0.04884675145149231
# Out:
# Loss: 0.054885676981490335
# mean_absolute_error: 0.05488567426800728
# Test Accuracy: 0.006172839552164078

# %%
# Plot training & validation accuracy values
import matplotlib.pyplot as plt
sns.set(style="whitegrid", palette="husl", rc={'figure.figsize':(11.7,8.27)})

plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy', fontsize=16)

plt.ylabel('accuracy')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# Plot training & validation loss values
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss', fontsize=16)
# increasing font size
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Training', 'Validation'], loc='upper right')
plt.show()

# %%
m.predict(X_test).T
# Out:
# array([[0.21669686, 0.6771643 , 0.3706749 , 0.33713716, 0.33894032,
#         0.45238733, 0.38447285, 0.4349044 , 0.5905417 , 0.21362276,
#         0.5142603 , 0.44871473, 0.38826686, 0.14447434, 0.26701462,
#         0.40026534, 0.44447297, 0.28536105, 0.20724073, 0.6543212 ,
#         0.35845208, 0.1761512 , 0.37773794, 0.7389496 , 0.18005295,
#         0.4577958 , 0.3455351 , 0.35644984, 0.35568792, 0.10755423,
#         0.25877833, 0.3742644 , 0.46937054, 0.34355253, 0.3562025 ,
#         0.8948085 , 0.32346648, 0.31199795, 0.26932588, 0.41323373,
#         0.8617553 , 0.18698552, 0.894724  , 0.161358  , 0.25090066,
#         0.1549985 , 0.55594176, 0.3764988 , 0.3720425 , 0.49781066,
#         0.22499642, 0.3533438 , 0.35113627, 0.7276679 , 0.43048427,
#         0.3890979 , 0.37626588, 0.32571653, 0.36930904, 0.6370415 ,
#         0.37975293, 0.72679996, 0.86495787, 0.31775874, 0.33247387,
#         0.4551987 , 0.32862663, 0.3531776 , 0.37618995, 0.522628  ,
#         0.20279166, 0.40768856, 0.35538906, 0.4506948 , 0.43698254,
#         0.4564559 , 0.27336833, 0.09276551, 0.46421114, 0.5239539 ,
#         0.33359933, 0.35764158, 0.52171946, 0.21805266, 0.46974596,
#         0.20601518, 0.38316476, 0.6650882 , 0.36556247, 0.20489359,
#         0.2268151 , 0.36854875, 0.56586295, 0.5327061 , 0.39630735,
#         0.33287436, 0.49243402, 0.20660381, 0.31951892, 0.50231016,
#         0.09409317, 0.13162027, 0.3360603 , 0.44379973, 0.34212726,
#         0.6759937 , 0.37179232, 0.34791267, 0.5830188 , 0.28321087,
#         0.6963274 , 0.36972597, 0.15222259, 0.5562526 , 0.41887462,
#         0.7369131 , 0.38502246, 0.7494587 , 0.14154676, 0.71837616,
#         0.55763626, 0.96462697, 0.4225535 , 0.3621647 , 0.10138139,
#         0.44586003, 0.6129253 , 0.38150835, 0.36765248, 0.43466735,
#         0.66999495, 0.5807879 , 0.24071428, 0.15401703, 0.4612373 ,
#         0.55268717, 0.100388  , 0.8536517 , 0.48731336, 0.3668248 ,
#         0.3746809 , 0.38265622, 0.36441514, 0.8935726 , 0.34436926,
#         0.21948336, 0.42851412, 0.23622592, 0.41988277, 0.24781677,
#         0.27068192, 0.27082622, 0.7720231 , 0.375268  , 0.68222797,
#         0.19575937, 0.37006152, 0.20723924, 0.4931352 , 0.33791953,
#         0.07456167, 0.21590233]], dtype=float32)

# %%
y_test
# Out:
# array([[0.19178082],
#        [0.6826484 ],
#        [0.23515982],
#        [0.25342466],
#        [0.26484018],
#        [0.26255708],
#        [0.41552511],
#        [0.4109589 ],
#        [0.56849315],
#        [0.20776256],
#        [0.40639269],
#        [0.44977169],
#        [0.34931507],
#        [0.18949772],
#        [0.23744292],
#        [0.42922374],
#        [0.40182648],
#        [0.34246575],
#        [0.21232877],
#        [0.59817352],
#        [0.31050228],
#        [0.07762557],
#        [0.32191781],
#        [0.60958904],
#        [0.08675799],
#        [0.46118721],
#        [0.33105023],
#        [0.31278539],
#        [0.33333333],
#        [0.12557078],
#        [0.21004566],
#        [0.34474886],
#        [0.44748858],
#        [0.2739726 ],
#        [0.33333333],
#        [0.98858447],
#        [0.38127854],
#        [0.35159817],
#        [0.24200913],
#        [0.38812785],
#        [0.88584475],
#        [0.1347032 ],
#        [0.9086758 ],
#        [0.12557078],
#        [0.26027397],
#        [0.18493151],
#        [0.43150685],
#        [0.42922374],
#        [0.56164384],
#        [0.42237443],
#        [0.2260274 ],
#        [0.50456621],
#        [0.32648402],
#        [0.6826484 ],
#        [0.30821918],
#        [0.36986301],
#        [0.32876712],
#        [0.38584475],
#        [0.35616438],
#        [0.62557078],
#        [0.4109589 ],
#        [0.63242009],
#        [0.8630137 ],
#        [0.37671233],
#        [0.38127854],
#        [0.42922374],
#        [0.31278539],
#        [0.36757991],
#        [0.4086758 ],
#        [0.41780822],
#        [0.17579909],
#        [0.35844749],
#        [0.39269406],
#        [0.38812785],
#        [0.44520548],
#        [0.4109589 ],
#        [0.26712329],
#        [0.02968037],
#        [0.37899543],
#        [0.82876712],
#        [0.25114155],
#        [0.2283105 ],
#        [0.43150685],
#        [0.20776256],
#        [0.44748858],
#        [0.1826484 ],
#        [0.43378995],
#        [0.42465753],
#        [0.33561644],
#        [0.17123288],
#        [0.19406393],
#        [0.36986301],
#        [0.56621005],
#        [0.41324201],
#        [0.51369863],
#        [0.30136986],
#        [0.45890411],
#        [0.29223744],
#        [0.24200913],
#        [0.44292237],
#        [0.08675799],
#        [0.15981735],
#        [0.28310502],
#        [0.39041096],
#        [0.30821918],
#        [0.60730594],
#        [0.44063927],
#        [0.38356164],
#        [0.52968037],
#        [0.26484018],
#        [0.64383562],
#        [0.35616438],
#        [0.        ],
#        [0.40639269],
#        [0.456621  ],
#        [0.64383562],
#        [0.44063927],
#        [0.70776256],
#        [0.13242009],
#        [0.6369863 ],
#        [0.48401826],
#        [0.99315068],
#        [0.40639269],
#        [0.25570776],
#        [0.05022831],
#        [0.43835616],
#        [0.59589041],
#        [0.40410959],
#        [0.28538813],
#        [0.41552511],
#        [0.73515982],
#        [0.52511416],
#        [0.30593607],
#        [0.15525114],
#        [0.43150685],
#        [0.52283105],
#        [0.24429224],
#        [0.64611872],
#        [0.44977169],
#        [0.3652968 ],
#        [0.32876712],
#        [0.31050228],
#        [0.38127854],
#        [0.76940639],
#        [0.32420091],
#        [0.21917808],
#        [0.43150685],
#        [0.18493151],
#        [0.49086758],
#        [0.2260274 ],
#        [0.15296804],
#        [0.29223744],
#        [0.79452055],
#        [0.34246575],
#        [0.71004566],
#        [0.21917808],
#        [0.39726027],
#        [0.41552511],
#        [0.42922374],
#        [0.31278539],
#        [0.20091324],
#        [0.26712329]])

# %%
m.evaluate(X_test, y_test)
# Out:
# 162/162 [==============================] - 0s 65us/step
# [0.05437243886199998, 0.05437244102358818, 0.006172839552164078]

# %%
# fit the model to the training data
y_pred = m.predict(X_test)

# %% [markdown]
# Let’s plot the predicted value against the actual value. The black broken line is the predicted values

# %% [markdown]
# ### To further visualize the predicted results, we can draw a regression plot.

# %%
y_test = scaler.inverse_transform(y_test)
y_pred = scaler.inverse_transform(y_pred)

# %%
import matplotlib.pyplot as plt

sns.set(style="whitegrid", palette="husl", rc={'figure.figsize':(11.7,8.27)})

#fig, ax = plt.subplots()
plt.scatter(y_test, y_pred)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=4)
plt.xlabel('Measured')
plt.ylabel('Predicted')
plt.legend(['Predicted', 'Measured'], loc='upper right')

title="Predicted vs Measured"

# increasing font size
plt.title(title, fontsize=16)

plt.show()

# %%
predictions = m.predict(X_test)
predictions_labels = scaler.inverse_transform(predictions)
#predictions_labels = scaler.inverse_transform(predictions)
predictions_labels
# Out:
# array([[14491.323],
#        [34659.797],
#        [21235.56 ],
#        [19766.607],
#        [19845.586],
#        [24814.564],
#        [21839.912],
#        [24048.812],
#        [30865.727],
#        [14356.677],
#        [27524.6  ],
#        [24653.705],
#        [22006.088],
#        [11327.976],
#        [16695.24 ],
#        [22531.621],
#        [24467.916],
#        [17498.814],
#        [14077.145],
#        [33659.266],
#        [20700.201],
#        [12715.423],
#        [21544.922],
#        [37365.992],
#        [12886.319],
#        [25051.455],
#        [20134.438],
#        [20612.504],
#        [20579.13 ],
#        [ 9710.875],
#        [16334.491],
#        [21392.781],
#        [25558.43 ],
#        [20047.602],
#        [20601.67 ],
#        [44192.61 ],
#        [19167.832],
#        [18665.51 ],
#        [16796.475],
#        [23099.639],
#        [42744.883],
#        [13189.967],
#        [44188.914],
#        [12067.48 ],
#        [15989.449],
#        [11788.934],
#        [29350.248],
#        [21490.646],
#        [21295.463],
#        [26804.105],
#        [14854.844],
#        [20476.459],
#        [20379.77 ],
#        [36871.855],
#        [23855.21 ],
#        [22042.488],
#        [21480.445],
#        [19266.385],
#        [21175.736],
#        [32902.418],
#        [21633.18 ],
#        [36833.836],
#        [42885.152],
#        [18917.834],
#        [19562.355],
#        [24937.703],
#        [19393.848],
#        [20469.18 ],
#        [21477.121],
#        [27891.105],
#        [13882.275],
#        [22856.758],
#        [20566.041],
#        [24740.432],
#        [24139.836],
#        [24992.768],
#        [16973.533],
#        [ 9063.129],
#        [25332.45 ],
#        [27949.18 ],
#        [19611.65 ],
#        [20664.701],
#        [27851.31 ],
#        [14550.707],
#        [25574.873],
#        [14023.465],
#        [21782.617],
#        [34130.863],
#        [21011.637],
#        [13974.34 ],
#        [14934.502],
#        [21142.436],
#        [29784.797],
#        [28332.525],
#        [22358.262],
#        [19579.896],
#        [26568.61 ],
#        [14049.247],
#        [18994.93 ],
#        [27001.184],
#        [ 9121.281],
#        [10764.968],
#        [19719.441],
#        [24438.428],
#        [19985.174],
#        [34608.523],
#        [21284.504],
#        [20238.576],
#        [30536.223],
#        [17404.637],
#        [35499.14 ],
#        [21193.998],
#        [11667.35 ],
#        [29363.863],
#        [23346.707],
#        [37276.793],
#        [21863.984],
#        [37826.29 ],
#        [11199.748],
#        [36464.875],
#        [29424.467],
#        [47250.66 ],
#        [23507.844],
#        [20862.814],
#        [ 9440.505],
#        [24528.668],
#        [31846.127],
#        [21710.066],
#        [21103.18 ],
#        [24038.43 ],
#        [34345.777],
#        [30438.51 ],
#        [15543.286],
#        [11745.946],
#        [25202.193],
#        [29207.697],
#        [ 9396.994],
#        [42389.945],
#        [26344.326],
#        [21066.928],
#        [21411.023],
#        [21760.344],
#        [20961.383],
#        [44138.48 ],
#        [20083.375],
#        [14613.371],
#        [23768.918],
#        [15346.695],
#        [23390.865],
#        [15854.375],
#        [16855.87 ],
#        [16862.19 ],
#        [38814.61 ],
#        [21436.74 ],
#        [34881.586],
#        [13574.261],
#        [21208.695],
#        [14077.079],
#        [26599.322],
#        [19800.877],
#        [ 8265.801],
#        [14456.522]], dtype=float32)

# %% [markdown]
# ### Evaluate

# %%
predictions_labels == scaler.inverse_transform(y_test)
# Out:
# array([[False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False]])

# %%
# how many are correct
(predictions_labels == scaler.inverse_transform(y_test)).sum()
# Out:
# 0

# %% [markdown]
# ### Ref:
# https://medium.com/@haydar_ai/learning-data-science-day-9-linear-regression-on-boston-housing-dataset-cd62a80775ef
# https://subscription.packtpub.com/book/big_data_and_business_intelligence/9781789804744/1/ch01lvl1sec11/our-first-analysis-the-boston-housing-dataset
#
# https://towardsdatascience.com/machine-learning-project-predicting-boston-house-prices-with-regression-b4e47493633d
#
# ### inferential statistics
# https://www.datavedas.com/inferential-statistics-in-python/
# https://en.wikipedia.org/wiki/P-value
#
# ## Correlation
# https://machinelearningmastery.com/how-to-use-correlation-to-understand-the-relationship-between-variables/
#
# https://rpubs.com/joelrudinas03/BostonHousingPrices

# %% [markdown]
# https://realpython.com/linear-regression-in-python/
#
# # Neural Network
# https://medium.com/datadriveninvestor/building-neural-network-using-keras-for-regression-ceee5a9eadff
#
#
# https://towardsdatascience.com/how-do-we-train-neural-networks-edd985562b73
#
# https://towardsdatascience.com/building-a-deep-learning-model-using-keras-1548ca149d37
#
# https://tensorflow.rstudio.com/keras/articles/tutorial_basic_regression.html
# https://cran.r-project.org/web/packages/keras/vignettes/getting_started.html
#
# https://olegleyz.github.io/boston_housing.html
